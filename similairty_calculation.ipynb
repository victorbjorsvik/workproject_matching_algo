# %% [markdown]
# ### Import

# %%
import os
import pandas as pd
from services.ResumeInfoExtraction import ResumeInfoExtraction
from services.JobInfoExtraction import JobInfoExtraction
from source.schemas.resumeextracted import ResumeExtractedModel # Let's reintroduce later on
from source.schemas.jobextracted import JobExtractedModel # Let's reintroduce later on
import fitz  # PyMuPDF
from sentence_transformers import SentenceTransformer, CrossEncoder
from sklearn.metrics.pairwise import cosine_similarity
from openai import OpenAI
from tenacity import retry, wait_random_exponential, stop_after_attempt
import markdown
import warnings 
import logging
import torch
import torch.nn.functional as F

logging.getLogger('pypdf').setLevel(logging.ERROR)
warnings.filterwarnings("ignore")

# %%
import main_try

# %%
df_resumes = main_try.get_resumes('resumes')

# %%
df_resumes = main_try.resume_extraction(df_resumes)
df_resumes
# Out:
#                          name  \
# 0         CV Ilaria Gioia eng
# 1                   CV Rick 2
# 2      CV.Ludovica Baccilieri
# 3              hanna_pedersen
# 4          Irene Abbatelli CV
# 5    Luca_Oeztekin-checkpoint
# 6       Resume_Billi_Leonardo
# 7                 Tim_gunkel2
# 8  victor_bjorsvik-checkpoint
#
#                                                  raw  \
# 0  Ilaria Gioia \n \n \n \nCONTACTS \n+39 3661699...
# 1  Riccardo Lombardo \n(+39) 338 214 2704 \nricca...
# 2   \nLUDOVICA BACCILIERI \n \n \n \n \n \n \n \n...
# 3   \n \n \n \n \n \n \n \n \nEDUCATION \n \nNova...
# 4   \n \n \nIRENE ABBATELLI \nRome, Italy \n(+39)...
# 5  LUCA OEZTEKIN\nLisbon, Portugal & Cologne, Ger...
# 6   \nLEONARDO BILLI  \n \n \n \n \n \nRome, Ital...
# 7  TIM GUNKEL  \n \n \n \n             \n \n \n  ...
# 8  VICTOR BJORSVIK \n \nLisbon, Portugal | +47 91...
#
#                                               Skills
# 0  [marketing, communications, Canva, Microsoft W...
# 1  [business, finance, business administration, c...
# 2  [business, marketing, code, customer relations...
# 3  [business, analytics, business administration,...
# 4  [business, analytics, data analysis, data visu...
# 5  [analytics, artificial intelligence, modelling...
# 6  [business, project management, finance, busine...
# 7  [business, analytics, machine learning, busine...
# 8  [accounting, big data, communications, busines...

# %%
df_resumes = df_resumes.iloc[[0]]
df_resumes
# Out:
#                   name                                                raw  \
# 0  CV Ilaria Gioia eng  Ilaria Gioia \n \n \n \nCONTACTS \n+39 3661699...
#
#                                               Skills
# 0  [marketing, communications, Canva, Microsoft W...

# %% [markdown]
# *conda install -c conda-forge openpyxl*

# %% [markdown]
# ### Skill_Role df

# %%
file_path = os.path.join('skills_roles_data', 'Technology Skills.xlsx')
df_skill_role = pd.read_excel(file_path)
df_skill_role
# Out:
#       O*NET-SOC Code                              Title  \
# 0         11-1011.00                   Chief Executives
# 1         11-1011.00                   Chief Executives
# 2         11-1011.00                   Chief Executives
# 3         11-1011.00                   Chief Executives
# 4         11-1011.00                   Chief Executives
# ...              ...                                ...
# 32622     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32623     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32624     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32625     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32626     53-7121.00  Tank Car, Truck, and Ship Loaders
#
#                                              Example  Commodity Code  \
# 0                                      Adobe Acrobat        43232202
# 1                                    AdSense Tracker        43232306
# 2                                     Atlassian JIRA        43232201
# 3                        Blackbaud The Raiser's Edge        43232303
# 4      ComputerEase construction accounting software        43231601
# ...                                              ...             ...
# 32622                                          Linux        43233004
# 32623                                Microsoft Excel        43232110
# 32624                      Microsoft Office software        43231513
# 32625                                   SAP software        43231602
# 32626                Warehouse management system WMS        43231506
#
#                                          Commodity Title Hot Technology  \
# 0                           Document management software              Y
# 1            Data base user interface and query software              N
# 2                              Content workflow software              Y
# 3          Customer relationship management CRM software              N
# 4                                    Accounting software              N
# ...                                                  ...            ...
# 32622                          Operating system software              Y
# 32623                               Spreadsheet software              Y
# 32624                              Office suite software              Y
# 32625          Enterprise resource planning ERP software              Y
# 32626  Materials requirements planning logistics and ...              N
#
#       In Demand
# 0             N
# 1             N
# 2             N
# 3             N
# 4             N
# ...         ...
# 32622         N
# 32623         N
# 32624         N
# 32625         N
# 32626         N
#
# [32627 rows x 7 columns]

# %%
df_skill_role = df_skill_role.drop(columns=['O*NET-SOC Code', 'Commodity Code', 'Commodity Title'])

# %%
df_skill_role_filtered = df_skill_role[(df_skill_role['Hot Technology'] == 'Y') & (df_skill_role['In Demand'] == 'Y')]
df_skill_role_filtered
# Out:
#                                                    Title  \
# 27                                      Chief Executives
# 29                                      Chief Executives
# 31                                      Chief Executives
# 57                         Chief Sustainability Officers
# 140                      General and Operations Managers
# ...                                                  ...
# 32460                                Aviation Inspectors
# 32464                                Aviation Inspectors
# 32474  Transportation Vehicle, Equipment and Systems ...
# 32475  Transportation Vehicle, Equipment and Systems ...
# 32476  Transportation Vehicle, Equipment and Systems ...
#
#                          Example Hot Technology In Demand
# 27               Microsoft Excel              Y         Y
# 29     Microsoft Office software              Y         Y
# 31          Microsoft PowerPoint              Y         Y
# 57     Microsoft Office software              Y         Y
# 140              Microsoft Excel              Y         Y
# ...                          ...            ...       ...
# 32460            Microsoft Excel              Y         Y
# 32464             Microsoft Word              Y         Y
# 32474            Microsoft Excel              Y         Y
# 32475  Microsoft Office software              Y         Y
# 32476          Microsoft Outlook              Y         Y
#
# [2020 rows x 4 columns]

# %%
df_skill_role_grouped = df_skill_role_filtered.groupby('Title')['Example'].apply(list).reset_index()
df_skill_role_grouped.rename(columns={'Example': 'Skills'}, inplace=True)
df_skill_role_grouped
# Out:
#                                                  Title  \
# 0                             Accountants and Auditors
# 1                                            Actuaries
# 2                     Administrative Services Managers
# 3    Adult Basic Education, Adult Secondary Educati...
# 4                             Advertising Sales Agents
# ..                                                 ...
# 448                              Wind Energy Engineers
# 449                   Wind Turbine Service Technicians
# 450                        Word Processors and Typists
# 451                                Writers and Authors
# 452                 Zoologists and Wildlife Biologists
#
#                                                 Skills
# 0    [Intuit QuickBooks, Microsoft Excel, Microsoft...
# 1    [Microsoft Excel, Microsoft Office software, M...
# 2    [Microsoft Excel, Microsoft Office software, M...
# 3         [Microsoft Excel, Microsoft Office software]
# 4    [Adobe Creative Cloud software, Adobe Illustra...
# ..                                                 ...
# 448  [C++, Microsoft Excel, Python, The MathWorks M...
# 449          [Microsoft Office software, SAP software]
# 450  [Microsoft Excel, Microsoft Office software, M...
# 451  [Adobe Photoshop, Microsoft Excel, Microsoft O...
# 452  [ESRI ArcGIS software, Microsoft Excel, Micros...
#
# [453 rows x 2 columns]

# %% [markdown]
# ### Job Description df

# %%
file_path_1 = os.path.join('skills_roles_data', 'Occupation Data.xlsx')
df_jobdescription = pd.read_excel(file_path_1)
df_jobdescription
# Out:
#      O*NET-SOC Code                                              Title  \
# 0        11-1011.00                                   Chief Executives
# 1        11-1011.03                      Chief Sustainability Officers
# 2        11-1021.00                    General and Operations Managers
# 3        11-1031.00                                        Legislators
# 4        11-2011.00                Advertising and Promotions Managers
# ...             ...                                                ...
# 1011     55-3014.00                 Artillery and Missile Crew Members
# 1012     55-3015.00             Command and Control Center Specialists
# 1013     55-3016.00                                           Infantry
# 1014     55-3018.00                                     Special Forces
# 1015     55-3019.00  Military Enlisted Tactical Operations and Air/...
#
#                                             Description
# 0     Determine and formulate policies and provide o...
# 1     Communicate and coordinate with management, sh...
# 2     Plan, direct, or coordinate the operations of ...
# 3     Develop, introduce, or enact laws and statutes...
# 4     Plan, direct, or coordinate advertising polici...
# ...                                                 ...
# 1011  Target, fire, and maintain weapons used to des...
# 1012  Operate and monitor communications, detection,...
# 1013  Operate weapons and equipment in ground combat...
# 1014  Implement unconventional operations by air, la...
# 1015  All military enlisted tactical operations and ...
#
# [1016 rows x 3 columns]

# %%
df_jobdescription.rename(columns={'Description': 'raw'}, inplace=True)
df_jobdescription = df_jobdescription.drop(columns=['O*NET-SOC Code'])

# %%
# Get unique titles from df_skill_role_grouped
unique_titles = df_skill_role_grouped['Title'].unique()

# Filter df_jobs to only include rows with titles in unique_titles
filtered_df_jobs = df_jobdescription[df_jobdescription['Title'].isin(unique_titles)]

filtered_df_jobs
# Out:
#                                                  Title  \
# 0                                     Chief Executives
# 1                        Chief Sustainability Officers
# 2                      General and Operations Managers
# 3                                          Legislators
# 4                  Advertising and Promotions Managers
# ..                                                 ...
# 967       Captains, Mates, and Pilots of Water Vessels
# 974                                Traffic Technicians
# 975                          Transportation Inspectors
# 976                                Aviation Inspectors
# 977  Transportation Vehicle, Equipment and Systems ...
#
#                                                    raw
# 0    Determine and formulate policies and provide o...
# 1    Communicate and coordinate with management, sh...
# 2    Plan, direct, or coordinate the operations of ...
# 3    Develop, introduce, or enact laws and statutes...
# 4    Plan, direct, or coordinate advertising polici...
# ..                                                 ...
# 967  Command or supervise operations of ships and w...
# 974  Conduct field studies to determine traffic vol...
# 975  Inspect equipment or goods in connection with ...
# 976  Inspect aircraft, maintenance procedures, air ...
# 977  Inspect and monitor transportation equipment, ...
#
# [453 rows x 2 columns]

# %%
# Convert the numpy array to a list
unique_titles_list = unique_titles.tolist()

# Define the file path
output_file_path = 'unique_titles.txt'

# Write the list to a text file
with open(output_file_path, 'w') as file:
    for title in unique_titles_list:
        file.write(f"{title}\n")

print(f"Unique titles have been written to {output_file_path}")
# Out:
# Unique titles have been written to unique_titles.txt

# %%
df_jobs = main_try.job_info_extraction(filtered_df_jobs)
df_jobs
# Out:
#                                                  Title  \
# 0                                     Chief Executives
# 1                        Chief Sustainability Officers
# 2                      General and Operations Managers
# 3                                          Legislators
# 4                  Advertising and Promotions Managers
# ..                                                 ...
# 967       Captains, Mates, and Pilots of Water Vessels
# 974                                Traffic Technicians
# 975                          Transportation Inspectors
# 976                                Aviation Inspectors
# 977  Transportation Vehicle, Equipment and Systems ...
#
#                                                    raw  \
# 0    Determine and formulate policies and provide o...
# 1    Communicate and coordinate with management, sh...
# 2    Plan, direct, or coordinate the operations of ...
# 3    Develop, introduce, or enact laws and statutes...
# 4    Plan, direct, or coordinate advertising polici...
# ..                                                 ...
# 967  Command or supervise operations of ships and w...
# 974  Conduct field studies to determine traffic vol...
# 975  Inspect equipment or goods in connection with ...
# 976  Inspect aircraft, maintenance procedures, air ...
# 977  Inspect and monitor transportation equipment, ...
Photographic Process Workers and Processing Machine Operators
Photonics Engineers
Photonics Technicians
Physicists
Political Science Teachers, Postsecondary
Power Plant Operators
Precision Agriculture Technicians
Prepress Technicians and Workers
Print Binding and Finishing Workers
Private Detectives and Investigators
Probation Officers and Correctional Treatment Specialists
Producers and Directors
Proofreaders and Copy Markers
Public Safety Telecommunicators
Radiation Therapists
Radio Frequency Identification Device Specialists
Radio, Cellular, and Tower Equipment Installers and Repairers
Radiologists
Railroad Brake, Signal, and Switch Operators and Locomotive Firers
Receptionists and Information Clerks
Recreation Workers
Rehabilitation Counselors
Reservation and Transportation Ticket Agents and Travel Clerks
Residential Advisors
Robotics Engineers
Robotics Technicians
Roustabouts, Oil and Gas
School Psychologists
Security and Fire Alarm Systems Installers
Semiconductor Processing Technicians
Separating, Filtering, Clarifying, Precipitating, and Still Machine Setters, Operators, and Tenders
Set and Exhibit Designers
Shipping, Receiving, and Inventory Clerks
Slaughterers and Meat Packers
Soil and Plant Scientists
Solar Energy Systems Engineers
Solar Sales Representatives and Assessors
Special Education Teachers, Middle School
Special Education Teachers, Secondary School
Special Effects Artists and Animators
Sports Medicine Physicians
Stationary Engineers and Boiler Operators
Structural Metal Fabricators and Fitters
Substance Abuse and Behavioral Disorder Counselors
Surveying and Mapping Technicians
Surveyors
Teaching Assistants, Postsecondary
Technical Writers
Telecommunications Engineering Specialists
Telecommunications Equipment Installers and Repairers, Except Line Installers
Telemarketers
Telephone Operators
Tellers
Tire Repairers and Changers
Traffic Technicians
Transportation Engineers
Transportation Inspectors
Transportation Planners
Transportation Vehicle, Equipment and Systems Inspectors, Except Aviation
Travel Agents
Urban and Regional Planners
Urologists
Water Resource Specialists
Water and Wastewater Treatment Plant and System Operators
Water/Wastewater Engineers
Weatherization Installers and Technicians
Weighers, Measurers, Checkers, and Samplers, Recordkeeping
Welding, Soldering, and Brazing Machine Setters, Operators, and Tenders
Wholesale and Retail Buyers, Except Farm Products
Wind Energy Engineers
Wind Turbine Service Technicians
Word Processors and Typists
Writers and Authors
Zoologists and Wildlife Biologists
"""  # Include the full roles text here

# Process the text to add quotation marks and make it a valid Python list
roles_to_remove = ['{}{}'.format(role.strip(), "'") for role in roles_text.strip().splitlines() if role.strip()]

# Revome the roles that are in the roles_to_remove list for df_skill_role_grouped

# Normalize the 'Title' column in result_df
df_jobs['Title_normalized'] = df_jobs['Title'].str.strip().str.lower()

# Fix roles_to_remove by stripping extra apostrophes and spaces, then normalize
roles_to_remove_normalized = [
    role.strip().lower().rstrip("'") for role in roles_to_remove  # Remove trailing apostrophe
]

# Filter out the roles to remove
df_jobs= df_jobs[~df_jobs['Title_normalized'].isin(roles_to_remove_normalized)]

# Drop the temporary normalized column
df_jobs = df_jobs.drop(columns=['Title_normalized'])



# Revome the roles that are in the roles_to_remove list for df_skill_role_grouped

# Normalize the 'Title' column in result_df
df_skill_role_grouped['Title_normalized'] = df_skill_role_grouped['Title'].str.strip().str.lower()

# Fix roles_to_remove by stripping extra apostrophes and spaces, then normalize
roles_to_remove_normalized = [
    role.strip().lower().rstrip("'") for role in roles_to_remove  # Remove trailing apostrophe
]

# Filter out the roles to remove
df_skill_role_grouped= df_skill_role_grouped[~df_skill_role_grouped['Title_normalized'].isin(roles_to_remove_normalized)]

# Drop the temporary normalized column
df_skill_role_grouped = df_skill_role_grouped.drop(columns=['Title_normalized'])'''
# Out:
# '# REMOVING SOME ROLES\n\n# Original multiline text\nroles_text = """\nAgents and Business Managers of Artists, Performers, and Athletes\nAdult Basic Education, Adult Secondary Education, and English as a Second Language Instructors\nAerospace Engineers\nAgents and Business Managersof Artists, Pereformers, and Athletes\nAgricultural Inspectors\nAgricultural Technicians\nAir Traffic Controllers\nAircraft Mechanics and Service Technicians\nAirfield Operations Specialists\nAnesthesiologists\nAnimal Control Workers\nAnthropologists and Archeologists\nAppraisers and Assessors of Real Estate\nArbitrators, Mediators, and Conciliators\nArchitects, Except Landscape and Naval\nArchitectural and Civil Drafters\nArchitectural and Engineering Managers\nArchitecture Teachers, Postsecondary\nArchivists\nArt Directors\nArt Therapists\nArt, Drama, and Music Teachers, Postsecondary\nAstronomers\nAthletes and Sports Competitors\nAtmospheric and Space Scientists\nAudio and Video Technicians\nAudiologists\nAutomotive Engineers\nAviation Inspectors\nAvionics Technicians\nBiochemists and Biophysicists\nBioengineers and Biomedical Engineers\nBioinformatics Scientists\nBiological Technicians\nBiologists\nBiostatisticians\nBroadcast Announcers and Radio Disc Jockeys\nBroadcast Technicians\nBrownfield Redevelopment Specialists and Site Managers\nBuyers and Purchasing Agents, Farm Products\nCalibration Technologists and Technicians\nCamera Operators, Television, Video, and Film\nCaptains, Mates, and Pilots of Water Vessels\nCardiologists\nCareer/Technical Education Teachers, Postsecondary\nCargo and Freight Agents\nCartographers and Photogrammetrists\nChefs and Head Cooks\nChemical Engineers\nChemical Equipment Operators and Tenders\nChemical Plant and System Operators\nChemical Technicians\nChemistry Teachers, Postsecondary\nChemists\nChild, Family, and School Social Workers\nCivil Engineering Technologists and Technicians\nCivil Engineers\nClaims Adjusters, Examiners, and Investigators\nClinical Nurse Specialists\nClinical Research Coordinators\nClinical and Counseling Psychologists\nCommunity Health Workers\nConcierges\nConservation Scientists\nConstruction and Building Inspectors\nControl and Valve Installers and Repairers, Except Mechanical Door\nCorrespondence Clerks\nCostume Attendants\nCourt, Municipal, and License Clerks\nCurators\nDental Assistants\nDetectives and Criminal Investigators\nDietetic Technicians\nDietitians and Nutritionists\nDirectors, Religious Activities and Education\nDispatchers, Except Police, Fire, and Ambulance\nEconomists\nEditors\nEducation Administrators, Kindergarten through Secondary\nEducation Administrators, Postsecondary\nEducation and Childcare Administrators, Preschool and Daycare\nEducational, Guidance, and Career Counselors and Advisors\nElectrical Engineers\nElectrical and Electronic Engineering Technologists and Technicians\nElectrical and Electronics Drafters\nElectrical and Electronics Installers and Repairers, Transportation Equipment\nElectrical and Electronics Repairers, Commercial and Industrial Equipment\nElectrical and Electronics Repairers, Powerhouse, Substation, and Relay\nEmergency Management Directors\nEmergency Medicine Physicians\nEnergy Auditors\nEnergy Engineers, Except Wind and Solar\nEntertainment and Recreation Managers, Except Gambling\nEnvironmental Engineering Technologists and Technicians\nEnvironmental Engineers\nEnvironmental Restoration Planners\nEnvironmental Science and Protection Technicians, Including Health\nEnvironmental Scientists and Specialists, Including Health\nEpidemiologists\nEtchers and Engravers\nExercise Physiologists\nFabric and Apparel Patternmakers\nFacilities Managers\nFamily Medicine Physicians\nFarm and Home Management Educators\nFarmers, Ranchers, and Other Agricultural Managers\nFashion Designers\nFile Clerks\nFinancial Examiners\nFine Artists, Including Painters, Sculptors, and Illustrators\nFire Inspectors and Investigators\nFire-Prevention and Protection En ...

# %%
def calc_similarity_one_cv(cv_df, job_df, parallel=False):
    """
    Calculate cosine similarity between a single CV and multiple job descriptions 
    based on MPNET embeddings of combined skills.
    """
    # Initialize the model
    model = SentenceTransformer('all-mpnet-base-v2')
    model.max_seq_length = 75
    model.tokenizer.padding_side = "right"
    model.eval()

    def add_eos(input_examples):
        """Helper function to add special tokens between each skill."""
        input_examples = [input_example + model.tokenizer.eos_token for input_example in input_examples]
        return input_examples

    # Extract and process the CV's skills
    cv_df['Skills_Text'] = cv_df['Skills'].apply(add_eos)
    cv_df['Skills_Text'] = cv_df['Skills_Text'].apply(
        lambda x: ' '.join(sorted(set(x))) if isinstance(x, list) else ''
    )
    cv_embedding = model.encode(
        cv_df['Skills_Text'].iloc[0],  # Assuming a single CV is provided
        batch_size=1,
        show_progress_bar=False
    )

    # Preprocess the job descriptions' skills
    job_df['Skills_Text'] = job_df['Skills'].apply(add_eos)
    job_df['Skills_Text'] = job_df['Skills_Text'].apply(
        lambda x: ' '.join(sorted(set(x))) if isinstance(x, list) else ''
    )
    job_embeddings = model.encode(
        job_df['Skills_Text'].tolist(),
        batch_size=32,
        num_workers=os.cpu_count() // 2 if parallel else 0,
        show_progress_bar=False
    )

    # Compute cosine similarity
    similarity_scores = cosine_similarity([cv_embedding], job_embeddings).flatten()

    # Add similarity scores to the job descriptions DataFrame
    job_df['similarity_score'] = similarity_scores

    # Rank the jobs by similarity score
    job_df['rank'] = job_df['similarity_score'].rank(ascending=False)

    # Return a DataFrame with the job titles, similarity scores, and ranks
    ranked_jobs = job_df[['Title', 'similarity_score', 'rank']].sort_values(by='rank', ascending=True)
    return ranked_jobs

# %%
analysis_data_skills = calc_similarity_one_cv(df_resumes, df_skill_role_grouped, parallel=True)
analysis_data_skills.head(20)
# Out:
#                                                  Title  similarity_score  rank
# 311                       Operations Research Analysts          0.814761   1.0
# 270  Market Research Analysts and Marketing Special...          0.814013   2.0
# 310                                   Online Merchants          0.810256   3.0
# 112                       Data Warehousing Specialists          0.797291   4.0
# 166                  Financial and Investment Analysts          0.784074   5.0
# 262                                 Logistics Analysts          0.784033   6.0
# 267                                Management Analysts          0.783032   7.0
# 89                           Computer Systems Analysts          0.770671   8.0
# 215                     Health Informatics Specialists          0.768180   9.0
# 350  Purchasing Agents, Except Wholesale, Retail, a...          0.768077  10.0
# 140                                    Energy Auditors          0.765117  11.0
# 196        Fraud Examiners, Investigators and Analysts          0.764569  12.0
# 124                                         Economists          0.763346  13.0
# 114                                Database Architects          0.763274  14.0
# 165                         Financial Risk Specialists          0.760560  15.0
# 375                                     Sales Managers          0.760466  17.5
# 378  Sales Representatives, Wholesale and Manufactu...          0.760466  17.5
# 377  Sales Representatives, Wholesale and Manufactu...          0.760466  17.5
# 180  First-Line Supervisors of Non-Retail Sales Wor...          0.760466  17.5
# 410                         Sustainability Specialists          0.757299  20.0

# %%
analysis_data_descr = calc_similarity_one_cv(df_resumes, df_jobs, parallel=True)
analysis_data_descr.head(20)
# Out:
#                                                  Title  similarity_score  rank
# 122                                Software Developers          0.556051   1.0
# 85   Market Research Analysts and Marketing Special...          0.532665   2.0
# 88                        Business Continuity Planners          0.522060   3.0
# 125                Web and Digital Interface Designers          0.512890   4.0
# 672                    Public Safety Telecommunicators          0.505920   5.0
# 109                          Computer Systems Analysts          0.495519   6.0
# 86                        Search Marketing Strategists          0.487660   7.0
# 407                                      Photographers          0.474484   8.5
# 139                       Operations Research Analysts          0.474484   8.5
# 154              Bioengineers and Biomedical Engineers          0.459994  10.0
# 142                                    Data Scientists          0.458650  11.0
# 299           Computer Science Teachers, Postsecondary          0.449474  12.0
# 371                Commercial and Industrial Designers          0.446761  13.0
# 90                                    Online Merchants          0.443604  14.0
# 636                                    Sales Engineers          0.437038  15.0
# 9                     Administrative Services Managers          0.434236  16.0
# 77                                 Logistics Engineers          0.432274  17.0
# 158                         Water/Wastewater Engineers          0.429689  18.0
# 777  Telecommunications Equipment Installers and Re...          0.427058  19.0
# 624                           Advertising Sales Agents          0.423315  21.0

# %% [markdown]
# **Example check**

# %%
df_resumes['Skills'].value_counts()
# Out:
# Skills
# [marketing, communications, Canva, Microsoft Word, Microsoft Excel, Microsoft PowerPoint, advertising, google analytics, WordPress, webflow, structured text]    1
# Name: count, dtype: int64

# %%
df_jobs[df_jobs['Title'] == 'Computer Systems Analysts']['Skills'].values[0]
# Out:
# ['engineering',
#  'business',
#  'data processing',
#  'operations research',
#  'systems management',
#  'schedule',
#  'software']

# %%
df_skill_role_grouped[df_skill_role_grouped['Title'] == 'Computer Systems Analysts']['Skills'].values[0]
# Out:
# ['Atlassian JIRA',
#  'Microsoft Excel',
#  'Microsoft Office software',
#  'Microsoft PowerPoint',
#  'Microsoft SharePoint',
#  'Microsoft Visio',
#  'Python',
#  'SAP software',
#  'ServiceNow',
#  'Structured query language SQL']

# %% [markdown]
# ### Similarity score calculation merged

# %%
# Merge the dataframes on the Title column
merged_skills = pd.merge(
    df_jobs[['Title', 'Skills']],
    df_skill_role_grouped[['Title', 'Skills']],
    on='Title',
    how='outer',
    suffixes=('_jobs', '_hard')
)

# Combine the lists from both 'Skills' columns into one
merged_skills['Skills'] = merged_skills.apply(
    lambda row: list(set(row['Skills_jobs'] or []) | set(row['Skills_hard'] or [])),
    axis=1
)

# Select only the 'Title' and merged 'Skills' columns
result_df = merged_skills[['Title', 'Skills']]

# %%
'''# Remove not related roles
roles_text = """
Agents and Business Managers of Artists, Performers, and Athletes
Adult Basic Education, Adult Secondary Education, and English as a Second Language Instructors
Aerospace Engineers
Agents and Business Managersof Artists, Pereformers, and Athletes
Agricultural Inspectors
Agricultural Technicians
Air Traffic Controllers
Aircraft Mechanics and Service Technicians
Airfield Operations Specialists
Anesthesiologists
Animal Control Workers
Anthropologists and Archeologists
Appraisers and Assessors of Real Estate
Arbitrators, Mediators, and Conciliators
Architects, Except Landscape and Naval
Architectural and Civil Drafters
Architectural and Engineering Managers
Architecture Teachers, Postsecondary
Archivists
Art Directors
Art Therapists
Art, Drama, and Music Teachers, Postsecondary
Astronomers
Athletes and Sports Competitors
Atmospheric and Space Scientists
Audio and Video Technicians
Audiologists
Automotive Engineers
Aviation Inspectors
Avionics Technicians
Biochemists and Biophysicists
Bioengineers and Biomedical Engineers
Bioinformatics Scientists
Biological Technicians
Biologists
Biostatisticians
Broadcast Announcers and Radio Disc Jockeys
Broadcast Technicians
Brownfield Redevelopment Specialists and Site Managers
Buyers and Purchasing Agents, Farm Products
Calibration Technologists and Technicians
Camera Operators, Television, Video, and Film
Captains, Mates, and Pilots of Water Vessels
Cardiologists
Career/Technical Education Teachers, Postsecondary
Cargo and Freight Agents
Cartographers and Photogrammetrists
Chefs and Head Cooks
Chemical Engineers
transportation Vehicle, Equipment and Systems Inspectors, Except Aviation
Travel Agents
Urban and Regional Planners
Urologists
Water Resource Specialists
Water and Wastewater Treatment Plant and System Operators
Water/Wastewater Engineers
Weatherization Installers and Technicians
Weighers, Measurers, Checkers, and Samplers, Recordkeeping
Welding, Soldering, and Brazing Machine Setters, Operators, and Tenders
Wholesale and Retail Buyers, Except Farm Products
Wind Energy Engineers
Wind Turbine Service Technicians
Word Processors and Typists
Writers and Authors
Zoologists and Wildlife Biologists
"""  # Include the full roles text here

# Process the text to add quotation marks and make it a valid Python list
roles_to_remove = ['{}{}'.format(role.strip(), "'") for role in roles_text.strip().splitlines() if role.strip()]

# Normalize the 'Title' column in result_df
result_df_1['Title_normalized'] = result_df_1['Title'].str.strip().str.lower()

# Fix roles_to_remove by stripping extra apostrophes and spaces, then normalize
roles_to_remove_normalized = [
    role.strip().lower().rstrip("'") for role in roles_to_remove  # Remove trailing apostrophe
]

# Filter out the roles to remove
result_df= result_df_1[~result_df_1['Title_normalized'].isin(roles_to_remove_normalized)]

# Drop the temporary normalized column
result_df = result_df.drop(columns=['Title_normalized'])
result_df'''
# Out:
# '# Remove not related roles\nroles_text = """\nAgents and Business Managers of Artists, Performers, and Athletes\nAdult Basic Education, Adult Secondary Education, and English as a Second Language Instructors\nAerospace Engineers\nAgents and Business Managersof Artists, Pereformers, and Athletes\nAgricultural Inspectors\nAgricultural Technicians\nAir Traffic Controllers\nAircraft Mechanics and Service Technicians\nAirfield Operations Specialists\nAnesthesiologists\nAnimal Control Workers\nAnthropologists and Archeologists\nAppraisers and Assessors of Real Estate\nArbitrators, Mediators, and Conciliators\nArchitects, Except Landscape and Naval\nArchitectural and Civil Drafters\nArchitectural and Engineering Managers\nArchitecture Teachers, Postsecondary\nArchivists\nArt Directors\nArt Therapists\nArt, Drama, and Music Teachers, Postsecondary\nAstronomers\nAthletes and Sports Competitors\nAtmospheric and Space Scientists\nAudio and Video Technicians\nAudiologists\nAutomotive Engineers\nAviation Inspectors\nAvionics Technicians\nBiochemists and Biophysicists\nBioengineers and Biomedical Engineers\nBioinformatics Scientists\nBiological Technicians\nBiologists\nBiostatisticians\nBroadcast Announcers and Radio Disc Jockeys\nBroadcast Technicians\nBrownfield Redevelopment Specialists and Site Managers\nBuyers and Purchasing Agents, Farm Products\nCalibration Technologists and Technicians\nCamera Operators, Television, Video, and Film\nCaptains, Mates, and Pilots of Water Vessels\nCardiologists\nCareer/Technical Education Teachers, Postsecondary\nCargo and Freight Agents\nCartographers and Photogrammetrists\nChefs and Head Cooks\nChemical Engineers\nChemical Equipment Operators and Tenders\nChemical Plant and System Operators\nChemical Technicians\nChemistry Teachers, Postsecondary\nChemists\nChild, Family, and School Social Workers\nCivil Engineering Technologists and Technicians\nCivil Engineers\nClaims Adjusters, Examiners, and Investigators\nClinical Nurse Specialists\nClinical Research Coordinators\nClinical and Counseling Psychologists\nCommunity Health Workers\nConcierges\nConservation Scientists\nConstruction and Building Inspectors\nControl and Valve Installers and Repairers, Except Mechanical Door\nCorrespondence Clerks\nCostume Attendants\nCourt, Municipal, and License Clerks\nCurators\nDental Assistants\nDetectives and Criminal Investigators\nDietetic Technicians\nDietitians and Nutritionists\nDirectors, Religious Activities and Education\nDispatchers, Except Police, Fire, and Ambulance\nEconomists\nEditors\nEducation Administrators, Kindergarten through Secondary\nEducation Administrators, Postsecondary\nEducation and Childcare Administrators, Preschool and Daycare\nEducational, Guidance, and Career Counselors and Advisors\nElectrical Engineers\nElectrical and Electronic Engineering Technologists and Technicians\nElectrical and Electronics Drafters\nElectrical and Electronics Installers and Repairers, Transportation Equipment\nElectrical and Electronics Repairers, Commercial and Industrial Equipment\nElectrical and Electronics Repairers, Powerhouse, Substation, and Relay\nEmergency Management Directors\nEmergency Medicine Physicians\nEnergy Auditors\nEnergy Engineers, Except Wind and Solar\nEntertainment and Recreation Managers, Except Gambling\nEnvironmental Engineering Technologists and Technicians\nEnvironmental Engineers\nEnvironmental Restoration Planners\nEnvironmental Science and Protection Technicians, Including Health\nEnvironmental Scientists and Specialists, Including Health\nEpidemiologists\nEtchers and Engravers\nExercise Physiologists\nFabric and Apparel Patternmakers\nFacilities Managers\nFamily Medicine Physicians\nFarm and Home Management Educators\nFarmers, Ranchers, and Other Agricultural Managers\nFashion Designers\nFile Clerks\nFinancial Examiners\nFine Artists, Including Painters, Sculptors, and Illustrators\nFire Inspectors and Investigators\nFire-Prevention and Protection Engineers\nFishing and Hun ...

# %%
analysis_data_combined = calc_similarity_one_cv(df_resumes, result_df, parallel=True)
analysis_data_combined.head(20)
# Out:
#                                                  Title  similarity_score  rank
# 310                                   Online Merchants          0.873433   1.0
# 270  Market Research Analysts and Marketing Special...          0.859978   2.0
# 311                       Operations Research Analysts          0.825312   3.0
# 200                               Fundraising Managers          0.811423   4.0
# 377  Sales Representatives, Wholesale and Manufactu...          0.811037   5.0
# 271                                 Marketing Managers          0.810743   6.0
# 350  Purchasing Agents, Except Wholesale, Retail, a...          0.803697   7.0
# 4                             Advertising Sales Agents          0.801381   8.0
# 199                                        Fundraisers          0.801172   9.0
# 180  First-Line Supervisors of Non-Retail Sales Wor...          0.798182  10.0
# 112                       Data Warehousing Specialists          0.797768  11.0
# 376  Sales Representatives of Services, Except Adve...          0.796687  12.0
# 35                          Billing and Posting Clerks          0.795235  13.0
# 378  Sales Representatives, Wholesale and Manufactu...          0.794565  14.0
# 309                             Office Clerks, General          0.794357  15.0
# 380                       Search Marketing Strategists          0.794199  16.0
# 262                                 Logistics Analysts          0.793637  17.0
# 0                             Accountants and Auditors          0.792599  18.0
# 166                  Financial and Investment Analysts          0.791079  19.0
# 433                         Treasurers and Controllers          0.790533  20.0

# %% [markdown]
# ##### **Example**

# %%
df_resumes['Skills'].value_counts()
# Out:
# Skills
# [marketing, communications, Canva, Microsoft Word, Microsoft Excel, Microsoft PowerPoint, advertising, google analytics, WordPress, webflow, structured text]    1
# Name: count, dtype: int64

# %%
#df_relevant[df_relevant['Title'] == 'Online Merchants']['raw'].values[0]
result_df[result_df['Title'] == 'Billing and Posting Clerks']['Skills'].values[0]
# Out:
# ['Microsoft Excel',
#  'Microsoft Office software',
#  'operations research',
#  'accounting',
#  'Microsoft Outlook',
#  'Microsoft Word',
#  'Microsoft PowerPoint']

# %% [markdown]
# ### Different calculation of similairty considering exact matching words

# %% [markdown]
# #### function with 4 methods

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import os

def calc_similarity_matching_words(cv_df, job_df, parallel=False):
    """
    Calculate cosine similarity between a single CV and multiple job descriptions,
    combining semantic similarity (via MPNET embeddings) and explicit keyword matching.
    """
    # Initialize the model
    model = SentenceTransformer('all-mpnet-base-v2')
    model.max_seq_length = 75
    model.tokenizer.padding_side = "right"

    def add_eos(input_examples):
        """Helper function to add special tokens between each skill."""
        input_examples = [input_example + model.tokenizer.eos_token for input_example in input_examples]
        return input_examples

    def explicit_match(title, skills, keywords):
        """
        Return the number of exact keyword matches in title or skills.
        """
        # Normalize the lists to lowercase and strip whitespace
        title_words = set(title.lower().split())
        skill_words = set(skill.lower().strip() for skill in skills)
        keyword_set = set(keyword.lower().strip() for keyword in keywords)

        # Check for exact matches in title or skills
        title_match = keyword_set & title_words  # Intersection of sets for title
        skills_match = keyword_set & skill_words  # Intersection of sets for skills

        # Return the total number of matches
        return len(title_match) + len(skills_match)
    
    # Compute alignment score logic
    def compute_alignment_score(job_skills, resume_skills, job_embeddings, resume_embeddings):
        """
        Compute alignment score based on individual skill similarity.
        """
        alignment_score = 0
        for i in range(len(job_skills)):
            if job_skills[i] in resume_skills:
                alignment_score += 1  # Exact match
            else:
                # Compute similarity with all resume embeddings
                max_similarity = max(cosine_similarity([job_embeddings[i]], resume_embeddings)[0])
                if max_similarity >= 0.4:
                    alignment_score += max_similarity
        # Normalize by the number of job skills
        return alignment_score / len(job_skills) if len(job_skills) > 0 else 0

    # Extract and process the CV's skills
    cv_df['Skills_Text'] = cv_df['Skills'].apply(add_eos)
    cv_df['Skills_Text'] = cv_df['Skills_Text'].apply(
        lambda x: ' '.join(sorted(set(x))) if isinstance(x, list) else ''
    )
    cv_embedding = model.encode(
        cv_df['Skills_Text'].iloc[0],  # Assuming a single CV is provided
        batch_size=1,
        show_progress_bar=False
    )

    # Preprocess the job descriptions' skills
    job_df['Skills_Text'] = job_df['Skills'].apply(add_eos)
    job_df['Skills_Text'] = job_df['Skills_Text'].apply(
        lambda x: ' '.join(sorted(set(x))) if isinstance(x, list) else ''
    )
    job_embeddings = model.encode(
        job_df['Skills_Text'].tolist(),
        batch_size=32,
        num_workers=os.cpu_count() // 2 if parallel else 0,
        show_progress_bar=False
    )

    # Compute semantic similarity
    similarity_scores = cosine_similarity([cv_embedding], job_embeddings).flatten()
    job_df['semantic_similarity'] = similarity_scores

    # Compute explicit matches
    cv_skills = cv_df['Skills'].iloc[0]
    job_df['word_matches'] = job_df.apply(
        lambda row: explicit_match(row['Title'], row['Skills'], cv_skills),
        axis=1
    )

    # Add total number of words in the role's skills
    job_df['total_skills_count'] = job_df['Skills'].apply(lambda x: len(x) if isinstance(x, list) else 0)

    # Compute alignment scores
    job_df['alignment_score'] = job_df.apply(
        lambda row: compute_alignment_score(
            row['Skills'], cv_skills, model.encode(row['Skills']), model.encode(cv_skills)
        ),
        axis=1
    )

    w = 0.8

    job_df['weighted_score'] = job_df['semantic_similarity']*(job_df['word_matches'] / job_df['total_skills_count'])
    job_df['weighted_score_2'] = job_df['semantic_similarity']* w + (job_df['word_matches'] / job_df['total_skills_count'])* (1-w)

    # Rank by final score
    job_df['rank_by_semantic'] = job_df['semantic_similarity'].rank(ascending=False)

   # Sort and return results with all relevant columns
    result_df_sorted = job_df[['Title', 'semantic_similarity', 'alignment_score', 'weighted_score', 'weighted_score_2',
                           'word_matches', 'total_skills_count', 'rank_by_semantic']].sort_values(by='rank_by_semantic', ascending=True)

    return result_df_sorted

# %%
analysis_data_words = calc_similarity_matching_words(df_resumes, result_df, parallel=True)

# %%
analysis_data_words.head(20)
# Out:
#                                                  Title  semantic_similarity  \
# 310                                   Online Merchants             0.873433
# 270  Market Research Analysts and Marketing Special...             0.859978
# 311                       Operations Research Analysts             0.825312
# 200                               Fundraising Managers             0.811423
# 377  Sales Representatives, Wholesale and Manufactu...             0.811037
# 271                                 Marketing Managers             0.810743
# 350  Purchasing Agents, Except Wholesale, Retail, a...             0.803697
# 4                             Advertising Sales Agents             0.801381
# 199                                        Fundraisers             0.801172
# 180  First-Line Supervisors of Non-Retail Sales Wor...             0.798182
# 112                       Data Warehousing Specialists             0.797768
# 376  Sales Representatives of Services, Except Adve...             0.796687
# 35                          Billing and Posting Clerks             0.795235
# 378  Sales Representatives, Wholesale and Manufactu...             0.794565
# 309                             Office Clerks, General             0.794357
# 380                       Search Marketing Strategists             0.794199
# 262                                 Logistics Analysts             0.793637
# 0                             Accountants and Auditors             0.792599
# 166                  Financial and Investment Analysts             0.791079
# 433                         Treasurers and Controllers             0.790533
#
#      alignment_score  weighted_score  weighted_score_2  word_matches  \
# 310         0.851594        0.499105          0.813032             4
# 270         0.718207        0.515987          0.807983             6
# 311         0.549857        0.150057          0.696614             2
# 200         0.678458        0.347753          0.734853             3
# 377         0.624868        0.270346          0.715496             2
# 271         0.698470        0.540495          0.781928             4
# 350         0.714194        0.301386          0.717958             3
# 4           0.679744        0.400690          0.741105             7
# 199         0.650249        0.300440          0.715938             3
# 180         0.641160        0.266061          0.705213             2
# 112         0.544257        0.122734          0.668984             2
# 376         0.549842        0.159337          0.677349             1
# 35          0.754932        0.340815          0.721902             3
# 378         0.597904        0.227019          0.692795             2
# 309         0.736567        0.340439          0.721200             3
# 380         0.657841        0.397099          0.735359             6
# 262         0.620995        0.158727          0.674909             2
# 0           0.638924        0.198150          0.684079             2
# 166         0.618814        0.175795          0.677308             2
# 433         0.653726        0.225866          0.689569             2
#
#      total_skills_count  rank_by_semantic
# 310                   7               1.0
# 270                  10               2.0
# 311                  11               3.0
# 200                   7               4.0
# 377                   6               5.0
# 271                   6               6.0
# 350                   8               7.0
# 4                    14               8.0
# 199                   8               9.0
# 180                   6              10.0
# 112                  13              11.0
# 376                   5              12.0
# 35                    7              13.0
# 378                   7              14.0
# 309                   7              15.0
# 380                  12              16.0
# 262                  10              17.0
# 0                     8              18.0
# 166                   9              19.0
# 433                   7              20.0

# %%
# Create a DataFrame sorted by alignment score in descending order (top 20 rows)
alignment_score_df = analysis_data_words.sort_values(by='alignment_score', ascending=False).head(20)

# Create a DataFrame sorted by weighted_score_2 in descending order (top 20 rows)
weighted_score_2_df = analysis_data_words.sort_values(by='weighted_score_2', ascending=False).head(20)

# Print or display the DataFrames to verify
weighted_score_2_df[['Title', 'weighted_score_2', 'semantic_similarity', 'word_matches', 'total_skills_count', 'rank_by_semantic']]
# Out:
#                                                  Title  weighted_score_2  \
# 310                                   Online Merchants          0.813032
# 270  Market Research Analysts and Marketing Special...          0.807983
# 271                                 Marketing Managers          0.781928
# 5                  Advertising and Promotions Managers          0.781081
# 32                                 Aviation Inspectors          0.763663
# 4                             Advertising Sales Agents          0.741105
# 380                       Search Marketing Strategists          0.735359
# 200                               Fundraising Managers          0.734853
# 345                      Proofreaders and Copy Markers          0.728661
# 339               Private Detectives and Investigators          0.725457
# 101                                    Cost Estimators          0.725457
# 237  Inspectors, Testers, Sorters, Samplers, and We...          0.725457
# 75                      Clinical Research Coordinators          0.725457
# 287            Meeting, Convention, and Event Planners          0.725457
# 302                Non-Destructive Testing Specialists          0.725457
# 249                        Labor Relations Specialists          0.725457
# 155                                Facilities Managers          0.725457
# 190                           Food Science Technicians          0.725457
# 162                                Financial Examiners          0.725457
# 103               Court, Municipal, and License Clerks          0.725457
#
#      semantic_similarity  word_matches  total_skills_count  rank_by_semantic
# 310             0.873433             4                   7               1.0
# 270             0.859978             6                  10               2.0
# 271             0.810743             4                   6               6.0
# 5               0.776351             4                   5              57.0
# 32              0.704579             3                   3             193.0
# 4               0.801381             7                  14               8.0
# 380             0.794199             6                  12              16.0
# 200             0.811423             3                   7               4.0
# 345             0.767969             4                   7              67.0
# 339             0.781821             3                   6              41.5
# 101             0.781821             3                   6              41.5
# 237             0.781821             3                   6              41.5
# 75              0.781821             3                   6              41.5
# 287             0.781821             3                   6              41.5
# 302             0.781821             3                   6              41.5
# 249             0.781821             3                   6              41.5
# 155             0.781821             3                   6              41.5
# 190             0.781821             3                   6              41.5
# 162             0.781821             3                   6              41.5
# 103             0.781821             3                   6              41.5

# %% [markdown]
# ##### Example check

# %%
df_resumes['Skills'].value_counts()
# Out:
# Skills
# [accounting, big data, communications, business, analytics, finance, data science, modelling, business administration, Python, logistic regression, web development, flask, html, css, JavaScript, testing, training model, python, pandas, sql, Apache Spark, machine learning, tensorflow, keras, c, R, Tableau]    1
# Name: count, dtype: int64

# %% [markdown]
# [marketing, communications, Canva, Microsoft Word, Microsoft Excel, Microsoft PowerPoint, advertising, google analytics, WordPress, webflow, structured text]
# [accounting, big data, communications, business, analytics, finance, data science, modelling, business administration, Python, logistic regression, web development, flask, html, css, JavaScript, testing, training model, python, pandas, sql, Apache Spark, machine learning, tensorflow, keras, c, R, Tableau]

# %%
result_df[result_df['Title'] == 'Court, Municipal, and License Clerks']['Skills'].values[0]
# Out:
# ['Microsoft Office software',
#  'operations research',
#  'Microsoft Excel',
#  'Microsoft Outlook',
#  'Microsoft Word',
#  'Microsoft PowerPoint']

# %%
result_df[result_df['Title'] == 'Sales Representatives, Wholesale and Manufacturing, Technical and Scientific Products']['Skills'].values[0]
# Out:
# ['engineering',
#  'Salesforce software',
#  'Microsoft Office software',
#  'operations research',
#  'Microsoft Excel',
#  'Microsoft Outlook',
#  'Microsoft PowerPoint']

# %%
result_df[result_df['Title'] == 'Operations Research Analysts']['Skills'].values[0]
# Out:
# ['Structured query language SQL',
#  'Microsoft Office software',
#  'Microsoft PowerPoint',
#  'Microsoft Excel',
#  'Tableau',
#  'software',
#  'Microsoft Outlook',
#  'Python',
#  'Salesforce software',
#  'operations research',
#  'Microsoft Power BI']

# %%
result_df[result_df['Title'] == 'Search Marketing Strategists'][['Title', 'semantic_similarity', 'alignment_score', 'weighted_score', 'weighted_score_2',
                           'word_matches', 'total_skills_count', 'rank_by_semantic']].sort_values(by='rank_by_semantic', ascending=True)
# Out:
#                             Title  semantic_similarity  alignment_score  \
# 380  Search Marketing Strategists             0.794199         0.657841
#
#      weighted_score  weighted_score_2  word_matches  total_skills_count  \
# 380        0.397099          0.646323             6                  12
#
#      rank_by_semantic
# 380              16.0

# %% [markdown]
# ### Previous trial

# %% [markdown]
# #### messed up function

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import os

def calc_similarity_new(cv_df, job_df, parallel=False):
    """
    Calculate cosine similarity between a single CV and multiple job descriptions,
    combining semantic similarity (via MPNET embeddings), explicit keyword matching,
    and an alignment score based on individual skill similarity.
    """
    # Initialize the model
    model = SentenceTransformer('all-mpnet-base-v2')
    model.max_seq_length = 75
    model.tokenizer.padding_side = "right"

    def add_eos(input_examples):
        """Helper function to add special tokens between each skill."""
        input_examples = [input_example + model.tokenizer.eos_token for input_example in input_examples]
        return input_examples

    def explicit_match(title, skills, keywords):
        """
        Return the number of exact keyword matches in title or skills.
        """
        # Normalize the lists to lowercase and strip whitespace
        title_words = set(title.lower().split())
        skill_words = set(skill.lower().strip() for skill in skills)
        keyword_set = set(keyword.lower().strip() for keyword in keywords)

        # Check for exact matches in title or skills
        title_match = keyword_set & title_words  # Intersection of sets for title
        skills_match = keyword_set & skill_words  # Intersection of sets for skills

        # Return the total number of matches
        return len(title_match) + len(skills_match)

    # Compute alignment score logic
    def compute_alignment_score(job_skills, resume_skills, job_embeddings, resume_embeddings):
        """
        Compute alignment score based on individual skill similarity.
        """
        alignment_score = 0
        for i in range(len(job_skills)):
            if job_skills[i] in resume_skills:
                alignment_score += 1  # Exact match
            else:
                # Compute similarity with all resume embeddings
                max_similarity = max(cosine_similarity([job_embeddings[i]], resume_embeddings)[0])
                if max_similarity >= 0.4:
                    alignment_score += max_similarity
        # Normalize by the number of job skills
        return alignment_score / len(job_skills) if len(job_skills) > 0 else 0

    # Extract and process the CV's skills
    cv_df['Skills_Text'] = cv_df['Skills'].apply(add_eos)
    cv_df['Skills_Text'] = cv_df['Skills_Text'].apply(
        lambda x: ' '.join(sorted(set(x))) if isinstance(x, list) else ''
    )
    cv_embedding = model.encode(
        cv_df['Skills_Text'].iloc[0],  # Assuming a single CV is provided
        batch_size=1,
        show_progress_bar=False
    )
    cv_skills = cv_df['Skills'].iloc[0]

    # Preprocess the job descriptions' skills
    job_df['Skills_Text'] = job_df['Skills'].apply(add_eos)
    job_df['Skills_Text'] = job_df['Skills_Text'].apply(
        lambda x: ' '.join(sorted(set(x))) if isinstance(x, list) else ''
    )
    job_embeddings = model.encode(
        job_df['Skills_Text'].tolist(),
        batch_size=32,
        num_workers=os.cpu_count() // 2 if parallel else 0,
        show_progress_bar=False
    )

    # Compute alignment scores
    job_df['alignment_score'] = job_df.apply(
        lambda row: compute_alignment_score(
            row['Skills'], cv_skills, model.encode(row['Skills']), model.encode(cv_skills)
        ),
        axis=1
    )

    # Compute semantic similarity
    similarity_scores = cosine_similarity([cv_embedding], job_embeddings).flatten()
    job_df['semantic_similarity'] = similarity_scores

    # Compute explicit matches
    job_df['word_matches'] = job_df.apply(
        lambda row: explicit_match(row['Title'], row['Skills'], cv_skills),
        axis=1
    )

    # Add total number of words in the role's skills
    job_df['total_skills_count'] = job_df['Skills'].apply(lambda x: len(x) if isinstance(x, list) else 0)

    # Compute the final score
    job_df['final_score'] = (
        job_df['semantic_similarity'] +  # semantic similarity
        job_df['word_matches'] +         # word match contribution
        job_df['alignment_score']        # alignment score
    )

    # Rank by final score
    job_df['rank'] = job_df['final_score'].rank(ascending=False)

    # Sort and return results with all relevant columns
    result_df_sorted = job_df[['Title', 'semantic_similarity', 
                                'word_matches ', 'total_skills_count', 'final_score', 'rank']].sort_values(by='rank', ascending=True)

    return result_df_sorted

# %%
analysis_data_words = calc_similarity_new(df_resumes, result_df, parallel=True)

# %%
analysis_data_words.head(20)

# %% [markdown]
# #### function with 20% of weight for matching words

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import os

def calc_similarity_with_explicit_match(cv_df, job_df, parallel=False):
    """
    Calculate cosine similarity between a single CV and multiple job descriptions,
    combining semantic similarity (via MPNET embeddings) and explicit keyword matching.
    """
    # Initialize the model
    model = SentenceTransformer('all-mpnet-base-v2')
    model.max_seq_length = 75
    model.tokenizer.padding_side = "right"
   
    def add_eos(input_examples):
        """Helper function to add special tokens between each skill."""
        input_examples = [input_example + model.tokenizer.eos_token for input_example in input_examples]
        return input_examples

    def explicit_match(title, skills, keywords):
        """
        Return the number of exact keyword matches in title or skills.
        """
        # Normalize the lists to lowercase and strip whitespace
        title_words = set(title.lower().split())
        skill_words = set(skill.lower().strip() for skill in skills)
        keyword_set = set(keyword.lower().strip() for keyword in keywords)

        # Check for exact matches in title or skills
        title_match = keyword_set & title_words  # Intersection of sets for title
        skills_match = keyword_set & skill_words  # Intersection of sets for skills

        # Return the total number of matches
        return len(title_match) + len(skills_match)
    
    def calculate_word_match_contribution(row, cv_skills):
        # Count the number of matches
        matches = explicit_match(row['Title'], row['Skills'], cv_skills)
        # Calculate the raw word_match_contribution
        raw_contribution = matches * row['semantic_similarity']
        return matches, raw_contribution

    # Extract and process the CV's skills
    cv_df['Skills_Text'] = cv_df['Skills'].apply(add_eos)
    cv_df['Skills_Text'] = cv_df['Skills_Text'].apply(
        lambda x: ' '.join(sorted(set(x))) if isinstance(x, list) else ''
    )
    cv_embedding = model.encode(
        cv_df['Skills_Text'].iloc[0],  # Assuming a single CV is provided
        batch_size=1,
        show_progress_bar=False
    )

    # Preprocess the job descriptions' skills
    job_df['Skills_Text'] = job_df['Skills'].apply(add_eos)
    job_df['Skills_Text'] = job_df['Skills_Text'].apply(
        lambda x: ' '.join(sorted(set(x))) if isinstance(x, list) else ''
    )
    job_embeddings = model.encode(
        job_df['Skills_Text'].tolist(),
        batch_size=32,
        num_workers=os.cpu_count() // 2 if parallel else 0,
        show_progress_bar=False
    )

    # Compute semantic similarity
    similarity_scores = cosine_similarity([cv_embedding], job_embeddings).flatten()
    job_df['semantic_similarity'] = similarity_scores

    # Compute explicit matches and word_match_contribution
    cv_skills = cv_df['Skills'].iloc[0]
    job_df['word_matches'], job_df['word_match_contribution_raw'] = zip(*job_df.apply(
        lambda row: calculate_word_match_contribution(row, cv_skills), axis=1
    ))

    # Handle edge case: if all contributions are the same, set a neutral normalized value
    min_contribution = job_df['word_match_contribution_raw'].min()
    max_contribution = job_df['word_match_contribution_raw'].max()
    if min_contribution == max_contribution:
        job_df['word_match_contribution'] = 0.5  # Set all to a neutral value
    else:
        # Normalize word_match_contribution between 0 and 1
        job_df['word_match_contribution'] = (
            (job_df['word_match_contribution_raw'] - min_contribution) /
            (max_contribution - min_contribution)
        )

    # Compute the final score
    job_df['final_score'] = (
        0.8 * job_df['semantic_similarity'] +  # 80% weight for semantic similarity
        0.2 * job_df['word_match_contribution']  # 20% weight for normalized word match contribution
    )

    # Rank by final score
    job_df['rank'] = job_df['final_score'].rank(ascending=False)

    # Sort and return results with all relevant columns
    result_df_sorted = job_df[['Title', 'semantic_similarity', 'word_matches', 
                               'word_match_contribution_raw', 'word_match_contribution', 
                               'final_score', 'rank']].sort_values(by='rank', ascending=True)

    return result_df_sorted

# %%
analysis_data_new = calc_similarity_with_explicit_match(df_resumes, result_df, parallel=True)

# %%
analysis_data_new.head(40)
# Out:
#                                                  Title  semantic_similarity  \
# 102  Market Research Analysts and Marketing Special...             0.859978
# 3                             Advertising Sales Agents             0.801381
# 108                                   Online Merchants             0.873433
# 137                       Search Marketing Strategists             0.794199
# 103                                 Marketing Managers             0.810743
# 78                                Fundraising Managers             0.811423
# 4                  Advertising and Promotions Managers             0.776351
# 121  Purchasing Agents, Except Wholesale, Retail, a...             0.803697
# 77                                         Fundraisers             0.801172
# 6                           Billing and Posting Clerks             0.795235
# 107                             Office Clerks, General             0.794357
# 109                       Operations Research Analysts             0.825312
# 64   First-Line Supervisors of Helpers, Laborers, a...             0.787203
# 96                                        Logisticians             0.787203
# 37            Credit Authorizers, Checkers, and Clerks             0.785628
# 81                      Health Informatics Specialists             0.784308
# 120                       Public Relations Specialists             0.753821
# 84                         Human Resources Specialists             0.781821
# 38                                   Credit Counselors             0.781821
# 82   Human Resources Assistants, Except Payroll and...             0.781821
# 21                                 Compliance Officers             0.781821
# 35                                     Cost Estimators             0.781821
# 36                                     Credit Analysts             0.781821
# 105            Meeting, Convention, and Event Planners             0.781821
# 129                     Regulatory Affairs Specialists             0.781821
# 138  Secretaries and Administrative Assistants, Exc...             0.781821
# 99                            Loss Prevention Managers             0.781821
# 135  Sales Representatives, Wholesale and Manufactu...             0.811037
# 2                     Administrative Services Managers             0.776326
# 104                        Media Programming Directors             0.770445
# 69   First-Line Supervisors of Non-Retail Sales Wor...             0.798182
# 43                        Data Warehousing Specialists             0.797768
# 117                     Project Management Specialists             0.765918
# 136  Sales Representatives, Wholesale and Manufactu...             0.794565
# 97                                  Logistics Analysts             0.793637
# 0                             Accountants and Auditors             0.792599
# 58                   Financial and Investment Analysts             0.791079
# 158                         Treasurers and Controllers             0.790533
# 133                                     Sales Managers             0.788956
# 149                         Sustainability Specialists             0.757299
#
#      word_matches  word_match_contribution_raw  word_match_contribution  \
# 102             6                     5.159871                 0.919818
# 3               7                     5.609666                 1.000000
# 108             4                     3.493733                 0.622806
# 137             6                     4.765194                 0.849461
# 103             4                     3.242973                 0.578104
# 78              3                     2.434270                 0.433942
# 4               4                     3.105404                 0.553581
# 121             3                     2.411092                 0.429810
# 77              3                     2.403517                 0.428460
# 6               3                     2.385706                 0.425285
# 107             3                     2.383071                 0.424815
# 109             2                     1.650625                 0.294247
# 64              3                     2.361608                 0.420989
# 96              3                     2.361608                 0.420989
# 37              3                     2.356885                 0.420147
# 81              3                     2.352925                 0.419441
# 120             4                     3.015285                 0.537516
# 84              3                     2.345464                 0.418111
# 38              3                     2.345464                 0.418111
# 82              3                     2.345464                 0.418111
# 21              3                     2.345464                 0.418111
# 35              3                     2.345464                 0.418111
# 36              3                     2.345464                 0.418111
# 105             3                     2.345464                 0.418111
# 129             3                     2.345464                 0.418111
# 138             3                     2.345464                 0.418111
# 99              3                     2.345464                 0.418111
# 135             2                     1.622073                 0.289157
# 2               3                     2.328978                 0.415172
# 104             3                     2.311336                 0.412027
# 69              2                     1.596365                 0.284574
# 43              2                     1.595537                 0.284426
# 117             3                     2.297753                 0.409606
# 136             2                     1.589130                 0.283284
# 97              2                     1.587273                 0.282953
# 0               2                     1.585198                 0.282583
# 58              2                     1.582158                 0.282041
# 158             2                     1.581065                 0.281847
# 133             2                     1.577913                 0.281285
# 149             3                     2.271896                 0.404997
#
#      final_score  rank
# 102     0.871946   1.0
# 3       0.841105   2.0
# 108     0.823308   3.0
# 137     0.805251   4.0
# 103     0.764215   5.0
# 78      0.735927   6.0
# 4       0.731797   7.0
# 121     0.728920   8.0
# 77      0.726630   9.0
# 6       0.721245  10.0
# 107     0.720449  11.0
# 109     0.719099  12.0
# 64      0.713960  13.5
# 96      0.713960  13.5
# 37      0.712532  15.0
# 81      0.711335  16.0
# 120     0.710560  17.0
# 84      0.709079  22.5
# 38      0.709079  22.5
# 82      0.709079  22.5
# 21      0.709079  22.5
# 35      0.709079  22.5
# 36      0.709079  22.5
# 105     0.709079  22.5
# 129     0.709079  22.5
# 138     0.709079  22.5
# 99      0.709079  22.5
# 135     0.706661  28.0
# 2       0.704095  29.0
# 104     0.698762  30.0
# 69      0.695461  31.0
# 43      0.695100  32.0
# 117     0.694655  33.0
# 136     0.692309  34.0
# 97      0.691500  35.0
# 0       0.690596  36.0
# 58      0.689271  37.0
# 158     0.688796  38.0
# 133     0.687422  39.0
# 149     0.686838  40.0

# %% [markdown]
# #### with 3 diffefrent weight for words matching based on list lenght

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import os

def calc_similarity_with_dynamic_weight_lenght(cv_df, job_df, parallel=False):
    """
    Calculate cosine similarity between a single CV and multiple job descriptions,
    combining semantic similarity (via MPNET embeddings) and explicit keyword matching,
    with dynamic word match weight adjustments based on the length of the skill lists.
    """
    # Initialize the model
    model = SentenceTransformer('all-mpnet-base-v2')
    model.max_seq_length = 75
    model.tokenizer.padding_side = "right"

    def add_eos(input_examples):
        """Helper function to add special tokens between each skill."""
        input_examples = [input_example + model.tokenizer.eos_token for input_example in input_examples]
        return input_examples

    def explicit_match(title, skills, keywords):
        """
        Return the number of exact keyword matches in title or skills.
        """
        # Normalize the lists to lowercase and strip whitespace
        title_words = set(title.lower().split())
        skill_words = set(skill.lower().strip() for skill in skills)
        keyword_set = set(keyword.lower().strip() for keyword in keywords)

        # Check for exact matches in title or skills
        title_match = keyword_set & title_words  # Intersection of sets for title
        skills_match = keyword_set & skill_words  # Intersection of sets for skills

        # Return the total number of matches
        return len(title_match) + len(skills_match)

    def calculate_word_match_contribution(row, cv_skills, max_word_match_contribution):
        # Calculate matches and contribution
        matches = explicit_match(row['Title'], row['Skills'], cv_skills)
        contribution = matches * row['semantic_similarity']
        # Normalize contribution based on max possible
        return contribution / max_word_match_contribution if max_word_match_contribution > 0 else 0

    def determine_word_match_weight(skill_count):
        """Determine the weight of word matches based on the number of skills."""
        if skill_count <= 3:
            return 0.10  # Short skill list
        elif skill_count <= 10:
            return 0.20  # Medium skill list
        else:
            return 0.25  # Long skill list

    # Extract and process the CV's skills
    cv_df['Skills_Text'] = cv_df['Skills'].apply(add_eos)
    cv_df['Skills_Text'] = cv_df['Skills_Text'].apply(
        lambda x: ' '.join(sorted(set(x))) if isinstance(x, list) else ''
    )
    cv_embedding = model.encode(
        cv_df['Skills_Text'].iloc[0],  # Assuming a single CV is provided
        batch_size=1,
        show_progress_bar=False
    )

    # Preprocess the job descriptions' skills
    job_df['Skills_Text'] = job_df['Skills'].apply(add_eos)
    job_df['Skills_Text'] = job_df['Skills_Text'].apply(
        lambda x: ' '.join(sorted(set(x))) if isinstance(x, list) else ''
    )
    job_embeddings = model.encode(
        job_df['Skills_Text'].tolist(),
        batch_size=32,
        num_workers=os.cpu_count() // 2 if parallel else 0,
        show_progress_bar=False
    )

    # Compute semantic similarity
    similarity_scores = cosine_similarity([cv_embedding], job_embeddings).flatten()
    job_df['semantic_similarity'] = similarity_scores

    # Compute word matches and contribution
    cv_skills = cv_df['Skills'].iloc[0]
    job_df['word_matches'] = job_df.apply(
        lambda row: explicit_match(row['Title'], row['Skills'], cv_skills),
        axis=1
    )
    max_word_match_contribution = job_df.apply(
        lambda row: row['word_matches'] * row['semantic_similarity'], axis=1
    ).max()

    job_df['word_match_contribution'] = job_df.apply(
        lambda row: calculate_word_match_contribution(row, cv_skills, max_word_match_contribution),
        axis=1
    )

    # Dynamically adjust the weight of word match contribution
    job_df['word_match_weight'] = job_df['Skills'].apply(
        lambda skills: determine_word_match_weight(len(skills))
    )

    # Compute the final score as a weighted combination
    job_df['final_score'] = (
        (1 - job_df['word_match_weight']) * job_df['semantic_similarity'] +
        job_df['word_match_weight'] * job_df['word_match_contribution']
    )

    # Sort by the final score
    result_df_sorted = job_df.sort_values(by='final_score', ascending=False).reset_index(drop=True)

    # Include relevant columns in the output
    result_df_sorted = result_df_sorted[[
        'Title', 'semantic_similarity', 'word_matches', 'word_match_contribution',
        'word_match_weight', 'final_score'
    ]]

    return result_df_sorted

# %%
analysis_data_new = calc_similarity_with_dynamic_weight_lenght(df_resumes, result_df, parallel=True)
analysis_data_new
