# %% [markdown]
# ### Import

# %%
import os
import pandas as pd
from services.ResumeInfoExtraction import ResumeInfoExtraction
from services.JobInfoExtraction import JobInfoExtraction
from source.schemas.resumeextracted import ResumeExtractedModel # Let's reintroduce later on
from source.schemas.jobextracted import JobExtractedModel # Let's reintroduce later on
import fitz  # PyMuPDF
from sentence_transformers import SentenceTransformer, CrossEncoder
from sklearn.metrics.pairwise import cosine_similarity
from openai import OpenAI
from tenacity import retry, wait_random_exponential, stop_after_attempt
import markdown
import warnings 
import logging
import torch
import torch.nn.functional as F

logging.getLogger('pypdf').setLevel(logging.ERROR)
warnings.filterwarnings("ignore")

# Get the absolute path of the root directory
ROOT_DIR = os.path.abspath(r'C:\Users\irene\OneDrive\Desktop\Thesis\MAIN_CODE')

# Paths to your pattern files
skills_patterns_path = os.path.join(ROOT_DIR, 'workproject_matching_algo','Resources', 'data', 'skills.jsonl')
# Out:
# c:\Users\irene\anaconda3\envs\workproject\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
import main

# %%
df_resumes = main.get_resumes('resumes')

# %%
df_resumes = main.resume_extraction(df_resumes)
df_resumes
# Out:
#                          name  \
# 0         CV Ilaria Gioia eng
# 1                   CV Rick 2
# 2      CV.Ludovica Baccilieri
# 3              hanna_pedersen
# 4          Irene Abbatelli CV
# 5    Luca_Oeztekin-checkpoint
# 6                 Tim_gunkel2
# 7  victor_bjorsvik-checkpoint
#
#                                                  raw  \
# 0  Ilaria Gioia \n \n \n \nCONTACTS \n+39 3661699...
# 1  Riccardo Lombardo \n(+39) 338 214 2704 \nricca...
# 2   \nLUDOVICA BACCILIERI \n \n \n \n \n \n \n \n...
# 3   \n \n \n \n \n \n \n \n \nEDUCATION \n \nNova...
# 4   \n \n \nIRENE ABBATELLI \nRome, Italy \n(+39)...
# 5  LUCA OEZTEKIN\nLisbon, Portugal & Cologne, Ger...
# 6  TIM GUNKEL  \n \n \n \n             \n \n \n  ...
# 7  VICTOR BJORSVIK \n \nLisbon, Portugal | +47 91...
#
#                                               Skills
# 0  [marketing, communications, Canva, Microsoft W...
# 1  [business, finance, business administration, c...
# 2  [business, marketing, code, customer relations...
# 3  [business, analytics, business administration,...
# 4  [business, analytics, data analysis, data visu...
# 5  [analytics, artificial intelligence, modelling...
# 6  [business, analytics, machine learning, busine...
# 7  [accounting, big data, communications, busines...

# %%
df_resumes = df_resumes.iloc[[-4]]
df_resumes
# Out:
#                  name                                                raw  \
# 4  Irene Abbatelli CV   \n \n \nIRENE ABBATELLI \nRome, Italy \n(+39)...
#
#                                               Skills
# 4  [business, analytics, data analysis, data visu...

# %% [markdown]
# *conda install -c conda-forge openpyxl*

# %% [markdown]
# ### Skill_Role df

# %%
file_path = os.path.join('skills_roles_data', 'Technology Skills.xlsx')
df_skill_role = pd.read_excel(file_path)
df_skill_role
# Out:
#       O*NET-SOC Code                              Title  \
# 0         11-1011.00                   Chief Executives
# 1         11-1011.00                   Chief Executives
# 2         11-1011.00                   Chief Executives
# 3         11-1011.00                   Chief Executives
# 4         11-1011.00                   Chief Executives
# ...              ...                                ...
# 32622     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32623     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32624     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32625     53-7121.00  Tank Car, Truck, and Ship Loaders
# 32626     53-7121.00  Tank Car, Truck, and Ship Loaders
#
#                                              Example  Commodity Code  \
# 0                                      Adobe Acrobat        43232202
# 1                                    AdSense Tracker        43232306
# 2                                     Atlassian JIRA        43232201
# 3                        Blackbaud The Raiser's Edge        43232303
# 4      ComputerEase construction accounting software        43231601
# ...                                              ...             ...
# 32622                                          Linux        43233004
# 32623                                Microsoft Excel        43232110
# 32624                      Microsoft Office software        43231513
# 32625                                   SAP software        43231602
# 32626                Warehouse management system WMS        43231506
#
#                                          Commodity Title Hot Technology  \
# 0                           Document management software              Y
# 1            Data base user interface and query software              N
# 2                              Content workflow software              Y
# 3          Customer relationship management CRM software              N
# 4                                    Accounting software              N
# ...                                                  ...            ...
# 32622                          Operating system software              Y
# 32623                               Spreadsheet software              Y
# 32624                              Office suite software              Y
# 32625          Enterprise resource planning ERP software              Y
# 32626  Materials requirements planning logistics and ...              N
#
#       In Demand
# 0             N
# 1             N
# 2             N
# 3             N
# 4             N
# ...         ...
# 32622         N
# 32623         N
# 32624         N
# 32625         N
# 32626         N
#
# [32627 rows x 7 columns]

# %%
df_skill_role = df_skill_role.drop(columns=['O*NET-SOC Code', 'Commodity Code', 'Commodity Title'])

# %%
df_skill_role_filtered = df_skill_role[(df_skill_role['Hot Technology'] == 'Y') & (df_skill_role['In Demand'] == 'Y')]
df_skill_role_filtered
# Out:
#                                                    Title  \
# 27                                      Chief Executives
# 29                                      Chief Executives
# 31                                      Chief Executives
# 57                         Chief Sustainability Officers
# 140                      General and Operations Managers
# ...                                                  ...
# 32460                                Aviation Inspectors
# 32464                                Aviation Inspectors
# 32474  Transportation Vehicle, Equipment and Systems ...
# 32475  Transportation Vehicle, Equipment and Systems ...
# 32476  Transportation Vehicle, Equipment and Systems ...
#
#                          Example Hot Technology In Demand
# 27               Microsoft Excel              Y         Y
# 29     Microsoft Office software              Y         Y
# 31          Microsoft PowerPoint              Y         Y
# 57     Microsoft Office software              Y         Y
# 140              Microsoft Excel              Y         Y
# ...                          ...            ...       ...
# 32460            Microsoft Excel              Y         Y
# 32464             Microsoft Word              Y         Y
# 32474            Microsoft Excel              Y         Y
# 32475  Microsoft Office software              Y         Y
# 32476          Microsoft Outlook              Y         Y
#
# [2020 rows x 4 columns]

# %%
df_skill_role_grouped = df_skill_role_filtered.groupby('Title')['Example'].apply(list).reset_index()
df_skill_role_grouped.rename(columns={'Example': 'Skills'}, inplace=True)
df_skill_role_grouped
# Out:
#                                                  Title  \
# 0                             Accountants and Auditors
# 1                                            Actuaries
# 2                     Administrative Services Managers
# 3    Adult Basic Education, Adult Secondary Educati...
# 4                             Advertising Sales Agents
# ..                                                 ...
# 448                              Wind Energy Engineers
# 449                   Wind Turbine Service Technicians
# 450                        Word Processors and Typists
# 451                                Writers and Authors
# 452                 Zoologists and Wildlife Biologists
#
#                                                 Skills
# 0    [Intuit QuickBooks, Microsoft Excel, Microsoft...
# 1    [Microsoft Excel, Microsoft Office software, M...
# 2    [Microsoft Excel, Microsoft Office software, M...
# 3         [Microsoft Excel, Microsoft Office software]
# 4    [Adobe Creative Cloud software, Adobe Illustra...
# ..                                                 ...
# 448  [C++, Microsoft Excel, Python, The MathWorks M...
# 449          [Microsoft Office software, SAP software]
# 450  [Microsoft Excel, Microsoft Office software, M...
# 451  [Adobe Photoshop, Microsoft Excel, Microsoft O...
# 452  [ESRI ArcGIS software, Microsoft Excel, Micros...
#
# [453 rows x 2 columns]

# %% [markdown]
# ### Job Description df

# %%
file_path_1 = os.path.join('skills_roles_data', 'Occupation Data.xlsx')
df_jobdescription = pd.read_excel(file_path_1)
df_jobdescription
# Out:
#      O*NET-SOC Code                                              Title  \
# 0        11-1011.00                                   Chief Executives
# 1        11-1011.03                      Chief Sustainability Officers
# 2        11-1021.00                    General and Operations Managers
# 3        11-1031.00                                        Legislators
# 4        11-2011.00                Advertising and Promotions Managers
# ...             ...                                                ...
# 1011     55-3014.00                 Artillery and Missile Crew Members
# 1012     55-3015.00             Command and Control Center Specialists
# 1013     55-3016.00                                           Infantry
# 1014     55-3018.00                                     Special Forces
# 1015     55-3019.00  Military Enlisted Tactical Operations and Air/...
#
#                                             Description
# 0     Determine and formulate policies and provide o...
# 1     Communicate and coordinate with management, sh...
# 2     Plan, direct, or coordinate the operations of ...
# 3     Develop, introduce, or enact laws and statutes...
# 4     Plan, direct, or coordinate advertising polici...
# ...                                                 ...
# 1011  Target, fire, and maintain weapons used to des...
# 1012  Operate and monitor communications, detection,...
# 1013  Operate weapons and equipment in ground combat...
# 1014  Implement unconventional operations by air, la...
# 1015  All military enlisted tactical operations and ...
#
# [1016 rows x 3 columns]

# %%
df_jobdescription.rename(columns={'Description': 'raw'}, inplace=True)
df_jobdescription = df_jobdescription.drop(columns=['O*NET-SOC Code'])

# %%
# Get unique titles from df_skill_role_grouped
unique_titles = df_skill_role_grouped['Title'].unique()

# Filter df_jobs to only include rows with titles in unique_titles
filtered_df_jobs = df_jobdescription[df_jobdescription['Title'].isin(unique_titles)]

filtered_df_jobs
# Out:
#                                                  Title  \
# 0                                     Chief Executives
# 1                        Chief Sustainability Officers
# 2                      General and Operations Managers
# 3                                          Legislators
# 4                  Advertising and Promotions Managers
# ..                                                 ...
# 967       Captains, Mates, and Pilots of Water Vessels
# 974                                Traffic Technicians
# 975                          Transportation Inspectors
# 976                                Aviation Inspectors
# 977  Transportation Vehicle, Equipment and Systems ...
#
#                                                    raw
# 0    Determine and formulate policies and provide o...
# 1    Communicate and coordinate with management, sh...
# 2    Plan, direct, or coordinate the operations of ...
# 3    Develop, introduce, or enact laws and statutes...
# 4    Plan, direct, or coordinate advertising polici...
# ..                                                 ...
# 967  Command or supervise operations of ships and w...
# 974  Conduct field studies to determine traffic vol...
# 975  Inspect equipment or goods in connection with ...
# 976  Inspect aircraft, maintenance procedures, air ...
# 977  Inspect and monitor transportation equipment, ...
#
# [453 rows x 2 columns]

# %%
df_jobs = main.job_info_extraction(filtered_df_jobs)
df_jobs
# Out:
#                                                  Title  \
# 0                                     Chief Executives
# 1                        Chief Sustainability Officers
# 2                      General and Operations Managers
# 3                                          Legislators
# 4                  Advertising and Promotions Managers
# ..                                                 ...
# 967       Captains, Mates, and Pilots of Water Vessels
# 974                                Traffic Technicians
# 975                          Transportation Inspectors
# 976                                Aviation Inspectors
# 977  Transportation Vehicle, Equipment and Systems ...
#
#                                                    raw                 Skills
# 0    Determine and formulate policies and provide o...                     []
# 1    Communicate and coordinate with management, sh...                     []
# 2    Plan, direct, or coordinate the operations of ...                     []
# 3    Develop, introduce, or enact laws and statutes...                     []
# 4    Plan, direct, or coordinate advertising polici...          [advertising]
# ..                                                 ...                    ...
# 967  Command or supervise operations of ships and w...                     []
# 974  Conduct field studies to determine traffic vol...  [traffic engineering]
# 975  Inspect equipment or goods in connection with ...                     []
# 976  Inspect aircraft, maintenance procedures, air ...       [communications]
# 977  Inspect and monitor transportation equipment, ...                     []
#
# [453 rows x 3 columns]

# %% [markdown]
# ### Similarity score calculation separated

# %%
# REMOVING SOME ROLES

# Original multiline text
roles_text = """
Adult Basic Education, Adult Secondary Education, and English as a Second Language Instructors
Aerospace Engineers
Agents and Business Managersof Artists, Pereformers, and Athletes
Agricultural Inspectors
Agricultural Technicians
Air Traffic Controllers
Aircraft Mechanics and Service Technicians
Airfield Operations Specialists
Shipping, Receiving, and Inventory Clerks
Slaughterers and Meat Packers
Soil and Plant Scientists
Solar Energy Systems Engineers
Solar Sales Representatives and Assessors
Special Education Teachers, Middle School
Special Education Teachers, Secondary School
Special Effects Artists and Animators
Sports Medicine Physicians
Stationary Engineers and Boiler Operators
Structural Metal Fabricators and Fitters
Substance Abuse and Behavioral Disorder Counselors
Surveying and Mapping Technicians
Surveyors
Teaching Assistants, Postsecondary
Technical Writers
Telecommunications Engineering Specialists
Telecommunications Equipment Installers and Repairers, Except Line Installers
Telemarketers
Telephone Operators
Tellers
Tire Repairers and Changers
Traffic Technicians
Transportation Engineers
Transportation Inspectors
Transportation Planners
Transportation Vehicle, Equipment and Systems Inspectors, Except Aviation
Travel Agents
Urban and Regional Planners
Urologists
Water Resource Specialists
Water and Wastewater Treatment Plant and System Operators
Water/Wastewater Engineers
Weatherization Installers and Technicians
Weighers, Measurers, Checkers, and Samplers, Recordkeeping
Welding, Soldering, and Brazing Machine Setters, Operators, and Tenders
Wholesale and Retail Buyers, Except Farm Products
Wind Energy Engineers
Wind Turbine Service Technicians
Word Processors and Typists
Writers and Authors
Zoologists and Wildlife Biologists
"""  # Include the full roles text here

# Process the text to add quotation marks and make it a valid Python list
roles_to_remove = ['{}{}'.format(role.strip(), "'") for role in roles_text.strip().splitlines() if role.strip()]

# Revome the roles that are in the roles_to_remove list for df_skill_role_grouped

# Normalize the 'Title' column in result_df
df_jobs['Title_normalized'] = df_jobs['Title'].str.strip().str.lower()

# Fix roles_to_remove by stripping extra apostrophes and spaces, then normalize
roles_to_remove_normalized = [
    role.strip().lower().rstrip("'") for role in roles_to_remove  # Remove trailing apostrophe
]

# Filter out the roles to remove
df_jobs= df_jobs[~df_jobs['Title_normalized'].isin(roles_to_remove_normalized)]

# Drop the temporary normalized column
df_jobs = df_jobs.drop(columns=['Title_normalized'])



# Revome the roles that are in the roles_to_remove list for df_skill_role_grouped

# Normalize the 'Title' column in result_df
df_skill_role_grouped['Title_normalized'] = df_skill_role_grouped['Title'].str.strip().str.lower()

# Fix roles_to_remove by stripping extra apostrophes and spaces, then normalize
roles_to_remove_normalized = [
    role.strip().lower().rstrip("'") for role in roles_to_remove  # Remove trailing apostrophe
]

# Filter out the roles to remove
df_skill_role_grouped= df_skill_role_grouped[~df_skill_role_grouped['Title_normalized'].isin(roles_to_remove_normalized)]

# Drop the temporary normalized column
df_skill_role_grouped = df_skill_role_grouped.drop(columns=['Title_normalized'])

# %%
def calc_similarity_one_cv(cv_df, job_df, parallel=False):
    """
    Calculate cosine similarity between a single CV and multiple job descriptions 
    based on MPNET embeddings of combined skills.
    """
    # Initialize the model
    model = SentenceTransformer('all-mpnet-base-v2')
    model.max_seq_length = 75
    model.tokenizer.padding_side = "right"
    model.eval()

    def add_eos(input_examples):
        """Helper function to add special tokens between each skill."""
        input_examples = [input_example + model.tokenizer.eos_token for input_example in input_examples]
        return input_examples

    # Extract and process the CV's skills
    cv_df['Skills_Text'] = cv_df['Skills'].apply(add_eos)
    cv_df['Skills_Text'] = cv_df['Skills_Text'].apply(
        lambda x: ' '.join(sorted(set(x))) if isinstance(x, list) else ''
    )
    cv_embedding = model.encode(
        cv_df['Skills_Text'].iloc[0],  # Assuming a single CV is provided
        batch_size=1,
        show_progress_bar=False
    )

    # Preprocess the job descriptions' skills
    job_df['Skills_Text'] = job_df['Skills'].apply(add_eos)
    job_df['Skills_Text'] = job_df['Skills_Text'].apply(
        lambda x: ' '.join(sorted(set(x))) if isinstance(x, list) else ''
    )
    job_embeddings = model.encode(
        job_df['Skills_Text'].tolist(),
        batch_size=32,
        num_workers=os.cpu_count() // 2 if parallel else 0,
        show_progress_bar=False
    )

    # Compute cosine similarity
    similarity_scores = cosine_similarity([cv_embedding], job_embeddings).flatten()

    # Add similarity scores to the job descriptions DataFrame
    job_df['similarity_score'] = similarity_scores

    # Rank the jobs by similarity score
    job_df['rank'] = job_df['similarity_score'].rank(ascending=False)

    # Return a DataFrame with the job titles, similarity scores, and ranks
    ranked_jobs = job_df[['Title', 'similarity_score', 'rank']].sort_values(by='rank', ascending=True)
    return ranked_jobs

# %%
analysis_data_skills = calc_similarity_one_cv(df_resumes, df_skill_role_grouped, parallel=True)
analysis_data_skills.head(20)
# Out:
#                                                  Title  similarity_score  rank
# 311                       Operations Research Analysts          0.814761   1.0
# 270  Market Research Analysts and Marketing Special...          0.814013   2.0
# 310                                   Online Merchants          0.810256   3.0
# 112                       Data Warehousing Specialists          0.797291   4.0
# 166                  Financial and Investment Analysts          0.784074   5.0
# 262                                 Logistics Analysts          0.784033   6.0
# 267                                Management Analysts          0.783032   7.0
# 89                           Computer Systems Analysts          0.770671   8.0
# 215                     Health Informatics Specialists          0.768180   9.0
# 350  Purchasing Agents, Except Wholesale, Retail, a...          0.768077  10.0
# 196        Fraud Examiners, Investigators and Analysts          0.764569  11.0
# 114                                Database Architects          0.763274  12.0
# 165                         Financial Risk Specialists          0.760560  13.0
# 377  Sales Representatives, Wholesale and Manufactu...          0.760466  15.5
# 378  Sales Representatives, Wholesale and Manufactu...          0.760466  15.5
# 375                                     Sales Managers          0.760466  15.5
# 180  First-Line Supervisors of Non-Retail Sales Wor...          0.760466  15.5
# 410                         Sustainability Specialists          0.757299  18.0
# 199                                        Fundraisers          0.755480  19.5
# 200                               Fundraising Managers          0.755480  19.5

# %%
analysis_data_descr = calc_similarity_one_cv(df_resumes, df_jobs, parallel=True)
analysis_data_descr.head(20)
# Out:
#                                                  Title  similarity_score  rank
# 122                                Software Developers          0.560794   1.0
# 88                        Business Continuity Planners          0.529020   2.0
# 125                Web and Digital Interface Designers          0.511481   3.0
# 85   Market Research Analysts and Marketing Special...          0.498152   4.0
# 109                          Computer Systems Analysts          0.478031   5.0
# 86                        Search Marketing Strategists          0.477820   6.0
# 299           Computer Science Teachers, Postsecondary          0.457414   7.0
# 142                                    Data Scientists          0.448681   8.0
# 371                Commercial and Industrial Designers          0.446761   9.0
# 90                                    Online Merchants          0.443604  10.0
# 77                                 Logistics Engineers          0.426750  11.0
# 9                     Administrative Services Managers          0.426484  12.0
# 636                                    Sales Engineers          0.421772  13.0
# 128                                 Web Administrators          0.408285  14.0
# 646       Bookkeeping, Accounting, and Auditing Clerks          0.403001  15.0
# 12           Computer and Information Systems Managers          0.402397  16.0
# 121                               Computer Programmers          0.401977  17.0
# 687                                 Desktop Publishers          0.397773  18.0
# 126                               Video Game Designers          0.392203  19.0
# 114                  Computer User Support Specialists          0.391757  20.0

# %% [markdown]
# **Example check**

# %%
df_resumes['Skills'].value_counts()
# Out:
# Skills
# [marketing, communications, Canva, Microsoft Word, Microsoft Excel, Microsoft PowerPoint, advertising, google analytics, WordPress, webflow, structured text]    1
# Name: count, dtype: int64

# %%
df_jobs[df_jobs['Title'] == 'Operations Research Analysts']['Skills'].values[0]
# Out:
# ['software']

# %%
df_skill_role_grouped[df_skill_role_grouped['Title'] == 'Operations Research Analysts']['Skills'].values[0]
# Out:
# ['Microsoft Excel',
#  'Microsoft Office software',
#  'Microsoft Outlook',
#  'Microsoft Power BI',
#  'Microsoft PowerPoint',
#  'Python',
#  'Salesforce software',
#  'Structured query language SQL',
#  'Tableau']

# %% [markdown]
# ### Similarity score calculation merged

# %%
# Merge the dataframes on the Title column
merged_skills = pd.merge(
    df_jobs[['Title', 'Skills']],
    df_skill_role_grouped[['Title', 'Skills']],
    on='Title',
    how='outer',
    suffixes=('_jobs', '_hard')
)

# Combine the lists from both 'Skills' columns into one
merged_skills['Skills'] = merged_skills.apply(
    lambda row: list(set(row['Skills_jobs'] or []) | set(row['Skills_hard'] or [])),
    axis=1
)

Recreation Workers
Rehabilitation Counselors
Reservation and Transportation Ticket Agents and Travel Clerks
Residential Advisors
Robotics Engineers
Robotics Technicians
Roustabouts, Oil and Gas
School Psychologists
Security and Fire Alarm Systems Installers
Semiconductor Processing Technicians
Separating, Filtering, Clarifying, Precipitating, and Still Machine Setters, Operators, and Tenders
Set and Exhibit Designers
Shipping, Receiving, and Inventory Clerks
Slaughterers and Meat Packers
Soil and Plant Scientists
Solar Energy Systems Engineers
Solar Sales Representatives and Assessors
Special Education Teachers, Middle School
Special Education Teachers, Secondary School
Special Effects Artists and Animators
Sports Medicine Physicians
Stationary Engineers and Boiler Operators
Structural Metal Fabricators and Fitters
Substance Abuse and Behavioral Disorder Counselors
Surveying and Mapping Technicians
Surveyors
Teaching Assistants, Postsecondary
Technical Writers
Telecommunications Engineering Specialists
Telecommunications Equipment Installers and Repairers, Except Line Installers
Telemarketers
Telephone Operators
Tellers
Tire Repairers and Changers
Traffic Technicians
Transportation Engineers
Transportation Inspectors
Transportation Planners
Transportation Vehicle, Equipment and Systems Inspectors, Except Aviation
Travel Agents
Urban and Regional Planners
Urologists
Water Resource Specialists
Water and Wastewater Treatment Plant and System Operators
Water/Wastewater Engineers
Weatherization Installers and Technicians
Weighers, Measurers, Checkers, and Samplers, Recordkeeping
Welding, Soldering, and Brazing Machine Setters, Operators, and Tenders
Wholesale and Retail Buyers, Except Farm Products
Wind Energy Engineers
Wind Turbine Service Technicians
Word Processors and Typists
Writers and Authors
Zoologists and Wildlife Biologists
"""  # Include the full roles text here

# Process the text to add quotation marks and make it a valid Python list
roles_to_remove = ['{}{}'.format(role.strip(), "'") for role in roles_text.strip().splitlines() if role.strip()]

# Normalize the 'Title' column in result_df
result_df_1['Title_normalized'] = result_df_1['Title'].str.strip().str.lower()

# Fix roles_to_remove by stripping extra apostrophes and spaces, then normalize
roles_to_remove_normalized = [
    role.strip().lower().rstrip("'") for role in roles_to_remove  # Remove trailing apostrophe
]

# Filter out the roles to remove
result_df= result_df_1[~result_df_1['Title_normalized'].isin(roles_to_remove_normalized)]

# Drop the temporary normalized column
result_df = result_df.drop(columns=['Title_normalized'])
result_df
# Out:
#                                    Title  \
# 0               Accountants and Auditors
# 1                              Actuaries
# 2       Administrative Services Managers
# 3               Advertising Sales Agents
# 4    Advertising and Promotions Managers
# ..                                   ...
# 160                 Validation Engineers
# 161                 Video Game Designers
# 162                   Web Administrators
# 163                       Web Developers
# 164  Web and Digital Interface Designers
#
#                                                 Skills
# 0    [Microsoft PowerPoint, Microsoft Excel, SAP so...
# 1    [Structured query language SQL, Python, Micros...
# 2    [Microsoft Word, Microsoft PowerPoint, Microso...
# 3    [Adobe Photoshop, Adobe Illustrator, Microsoft...
# 4    [advertising, Microsoft Office software, Micro...
# ..                                                 ...
# 160  [Microsoft PowerPoint, Python, Microsoft Excel...
# 161  [Adobe Photoshop, JavaScript, C, Python, C#, O...
# 162  [Microsoft SharePoint, Structured query langua...
# 163  [Python, web development, Google Angular, jQue...
# 164  [Oracle Java, software, Git, Google Angular, R...
#
# [165 rows x 2 columns]

# %%
analysis_data_combined = calc_similarity_one_cv(df_resumes, result_df, parallel=True)
analysis_data_combined.head(20)
# Out:
#                                                  Title  similarity_score  rank
# 109                                   Online Merchants          0.873433   1.0
# 103  Market Research Analysts and Marketing Special...          0.847964   2.0
# 104                                 Marketing Managers          0.840032   3.0
# 110                       Operations Research Analysts          0.811473   4.0
# 70   First-Line Supervisors of Non-Retail Sales Wor...          0.798182   5.0
# 137  Sales Representatives, Wholesale and Manufactu...          0.797481   6.0
# 44                        Data Warehousing Specialists          0.797263   7.0
# 82                      Health Informatics Specialists          0.784308   8.0
# 59                   Financial and Investment Analysts          0.784074   9.0
# 98                                  Logistics Analysts          0.784033  10.0
# 138                       Search Marketing Strategists          0.783835  11.0
# 134                                     Sales Managers          0.783710  12.0
# 102                                Management Analysts          0.781670  13.0
# 78                                         Fundraisers          0.775698  14.0
# 9         Bookkeeping, Accounting, and Auditing Clerks          0.771823  15.0
# 56                                  Financial Managers          0.768192  16.0
# 122  Purchasing Agents, Except Wholesale, Retail, a...          0.768077  17.0
# 3                             Advertising Sales Agents          0.767293  18.0
# 0                             Accountants and Auditors          0.763820  19.0
# 13                      Business Intelligence Analysts          0.760627  20.0

# %% [markdown]
# **Example**

# %%
df_resumes['Skills'].value_counts()
# Out:
# Skills
# [marketing, communications, Canva, Microsoft Word, Microsoft Excel, Microsoft PowerPoint, advertising, google analytics, WordPress, webflow, structured text]    1
# Name: count, dtype: int64

# %%
#df_relevant[df_relevant['Title'] == 'Online Merchants']['raw'].values[0]
result_df[result_df['Title'] == 'Health Informatics Specialists']['Skills'].values[0]
# Out:
# ['Microsoft Office software',
#  'Microsoft PowerPoint',
#  'SAS',
#  'Microsoft Word',
#  'Tableau',
#  'design',
#  'Structured query language SQL',
#  'Microsoft Outlook',
#  'Microsoft Excel']

# %% [markdown]
# ### Different calculation of similairty considering exact matching words

# %% [markdown]
# #### function with 20% of weight for matching words

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import os

def calc_similarity_with_explicit_match(cv_df, job_df, parallel=False):
    """
    Calculate cosine similarity between a single CV and multiple job descriptions,
    combining semantic similarity (via MPNET embeddings) and explicit keyword matching.
    """
    # Initialize the model
    model = SentenceTransformer('all-mpnet-base-v2')
    model.max_seq_length = 75
    model.tokenizer.padding_side = "right"
   
    def add_eos(input_examples):
        """Helper function to add special tokens between each skill."""
        input_examples = [input_example + model.tokenizer.eos_token for input_example in input_examples]
        return input_examples

    def explicit_match(title, skills, keywords):
        """
        Return the number of exact keyword matches in title or skills.
        """
        # Normalize the lists to lowercase and strip whitespace
        title_words = set(title.lower().split())
        skill_words = set(skill.lower().strip() for skill in skills)
        keyword_set = set(keyword.lower().strip() for keyword in keywords)

        # Check for exact matches in title or skills
        title_match = keyword_set & title_words  # Intersection of sets for title
        skills_match = keyword_set & skill_words  # Intersection of sets for skills

        # Return the total number of matches
        return len(title_match) + len(skills_match)
    
    def calculate_word_match_contribution(row, cv_skills):
        # Count the number of matches
        matches = explicit_match(row['Title'], row['Skills'], cv_skills)
        # Calculate the raw word_match_contribution
        raw_contribution = matches * row['semantic_similarity']
        return matches, raw_contribution

    # Extract and process the CV's skills
    cv_df['Skills_Text'] = cv_df['Skills'].apply(add_eos)
    cv_df['Skills_Text'] = cv_df['Skills_Text'].apply(
        lambda x: ' '.join(sorted(set(x))) if isinstance(x, list) else ''
    )
    cv_embedding = model.encode(
        cv_df['Skills_Text'].iloc[0],  # Assuming a single CV is provided
        batch_size=1,
        show_progress_bar=False
    )

    # Preprocess the job descriptions' skills
    job_df['Skills_Text'] = job_df['Skills'].apply(add_eos)
    job_df['Skills_Text'] = job_df['Skills_Text'].apply(
        lambda x: ' '.join(sorted(set(x))) if isinstance(x, list) else ''
    )
    job_embeddings = model.encode(
        job_df['Skills_Text'].tolist(),
        batch_size=32,
        num_workers=os.cpu_count() // 2 if parallel else 0,
        show_progress_bar=False
    )

    # Compute semantic similarity
    similarity_scores = cosine_similarity([cv_embedding], job_embeddings).flatten()
    job_df['semantic_similarity'] = similarity_scores

    # Compute explicit matches and word_match_contribution
    cv_skills = cv_df['Skills'].iloc[0]
    job_df['word_matches'], job_df['word_match_contribution_raw'] = zip(*job_df.apply(
        lambda row: calculate_word_match_contribution(row, cv_skills), axis=1
    ))

    # Handle edge case: if all contributions are the same, set a neutral normalized value
    min_contribution = job_df['word_match_contribution_raw'].min()
    max_contribution = job_df['word_match_contribution_raw'].max()
    if min_contribution == max_contribution:
        job_df['word_match_contribution'] = 0.5  # Set all to a neutral value
    else:
        # Normalize word_match_contribution between 0 and 1
        job_df['word_match_contribution'] = (
            (job_df['word_match_contribution_raw'] - min_contribution) /
            (max_contribution - min_contribution)
        )

    # Compute the final score
    job_df['final_score'] = (
        0.8 * job_df['semantic_similarity'] +  # 80% weight for semantic similarity
        0.2 * job_df['word_match_contribution']  # 20% weight for normalized word match contribution
    )

    # Rank by final score
    job_df['rank'] = job_df['final_score'].rank(ascending=False)

    # Sort and return results with all relevant columns
    result_df_sorted = job_df[['Title', 'semantic_similarity', 'word_matches', 
                               'word_match_contribution_raw', 'word_match_contribution', 
                               'final_score', 'rank']].sort_values(by='rank', ascending=True)

    return result_df_sorted

# %%
analysis_data_new = calc_similarity_with_explicit_match(df_resumes, result_df, parallel=True)

# %%
analysis_data_new.head(20)
# Out:
#                                                 Title  semantic_similarity  \
# 0   Market Research Analysts and Marketing Special...             0.847964
# 1                                    Online Merchants             0.873433
# 2                            Advertising Sales Agents             0.767293
# 3                        Search Marketing Strategists             0.783835
# 4                                  Marketing Managers             0.840032
# 5                 Advertising and Promotions Managers             0.755447
# 6                      Health Informatics Specialists             0.784308
# 7                        Operations Research Analysts             0.811473
# 8                                         Fundraisers             0.775698
# 9   Purchasing Agents, Except Wholesale, Retail, a...             0.768077
# 10  First-Line Supervisors of Non-Retail Sales Wor...             0.798182
# 11  Sales Representatives, Wholesale and Manufactu...             0.797481
# 12                         Sustainability Specialists             0.757299
# 13           Credit Authorizers, Checkers, and Clerks             0.756889
# 14                               Fundraising Managers             0.755480
# 15                         Billing and Posting Clerks             0.755216
# 16               Training and Development Specialists             0.754118
# 17                  Financial and Investment Analysts             0.784074
# 18                                 Logistics Analysts             0.784033
# 19                                     Sales Managers             0.783710
#
#     word_matches  word_match_contribution  word_match_weight  final_score
# 0              6                 0.947261               0.20     0.867824
# 1              4                 0.650475               0.20     0.828841
# 2              7                 1.000000               0.25     0.825470
# 3              6                 0.875622               0.25     0.806782
# 4              4                 0.625599               0.20     0.797145
# 5              4                 0.562606               0.20     0.716879
# 6              3                 0.438075               0.20     0.715062
# 7              2                 0.302165               0.20     0.709612
# 8              3                 0.433266               0.20     0.707212
# 9              3                 0.429009               0.20     0.700264
# 10             2                 0.297216               0.20     0.697989
# 11             2                 0.296955               0.20     0.697376
# 12             3                 0.422989               0.20     0.690437
# 13             3                 0.422760               0.20     0.690063
# 14             3                 0.421973               0.20     0.688779
# 15             3                 0.421826               0.20     0.688538
# 16             3                 0.421212               0.20     0.687537
# 17             2                 0.291963               0.20     0.685651
# 18             2                 0.291948               0.20     0.685616
# 19             2                 0.291827               0.20     0.685334

# %% [markdown]
# #### Example Check

# %%
df_resumes['Skills'].value_counts()
# Out:
# Skills
# [business, marketing, customer relationship management, business administration, international trade, communications, design, wordpress, advertising, Canva]    1
# Name: count, dtype: int64

# %%
#df_relevant[df_relevant['Title'] == 'Online Merchants']['raw'].values[0]
result_df[result_df['Title'] == 'Computer Science Teachers, Postsecondary']['Skills'].values[0]
# Out:
# ['computer science',
#  'Python',
#  'design',
#  'Oracle Java',
#  'C++',
#  'Microsoft Office software',
#  'Linux']

# %% [markdown]
# #### with 3 diffefrent weight for words matching based on list lenght

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import os

def calc_similarity_with_dynamic_weight_lenght(cv_df, job_df, parallel=False):
    """
    Calculate cosine similarity between a single CV and multiple job descriptions,
    combining semantic similarity (via MPNET embeddings) and explicit keyword matching,
    with dynamic word match weight adjustments based on the length of the skill lists.
    """
    # Initialize the model
    model = SentenceTransformer('all-mpnet-base-v2')
    model.max_seq_length = 75
    model.tokenizer.padding_side = "right"

    def add_eos(input_examples):
        """Helper function to add special tokens between each skill."""
        input_examples = [input_example + model.tokenizer.eos_token for input_example in input_examples]
        return input_examples

    def explicit_match(title, skills, keywords):
        """
        Return the number of exact keyword matches in title or skills.
        """
        # Normalize the lists to lowercase and strip whitespace
        title_words = set(title.lower().split())
        skill_words = set(skill.lower().strip() for skill in skills)
        keyword_set = set(keyword.lower().strip() for keyword in keywords)

        # Check for exact matches in title or skills
        title_match = keyword_set & title_words  # Intersection of sets for title
        skills_match = keyword_set & skill_words  # Intersection of sets for skills

        # Return the total number of matches
        return len(title_match) + len(skills_match)

    def calculate_word_match_contribution(row, cv_skills, max_word_match_contribution):
        # Calculate matches and contribution
        matches = explicit_match(row['Title'], row['Skills'], cv_skills)
        contribution = matches * row['semantic_similarity']
        # Normalize contribution based on max possible
        return contribution / max_word_match_contribution if max_word_match_contribution > 0 else 0

    def determine_word_match_weight(skill_count):
        """Determine the weight of word matches based on the number of skills."""
        if skill_count <= 3:
            return 0.10  # Short skill list
        elif skill_count <= 10:
            return 0.20  # Medium skill list
        else:
            return 0.25  # Long skill list

    # Extract and process the CV's skills
    cv_df['Skills_Text'] = cv_df['Skills'].apply(add_eos)
    cv_df['Skills_Text'] = cv_df['Skills_Text'].apply(
        lambda x: ' '.join(sorted(set(x))) if isinstance(x, list) else ''
    )
    cv_embedding = model.encode(
        cv_df['Skills_Text'].iloc[0],  # Assuming a single CV is provided
        batch_size=1,
        show_progress_bar=False
    )

    # Preprocess the job descriptions' skills
    job_df['Skills_Text'] = job_df['Skills'].apply(add_eos)
    job_df['Skills_Text'] = job_df['Skills_Text'].apply(
        lambda x: ' '.join(sorted(set(x))) if isinstance(x, list) else ''
    )
    job_embeddings = model.encode(
        job_df['Skills_Text'].tolist(),
        batch_size=32,
        num_workers=os.cpu_count() // 2 if parallel else 0,
        show_progress_bar=False
    )

    # Compute semantic similarity
    similarity_scores = cosine_similarity([cv_embedding], job_embeddings).flatten()
    job_df['semantic_similarity'] = similarity_scores

    # Compute word matches and contribution
    cv_skills = cv_df['Skills'].iloc[0]
    job_df['word_matches'] = job_df.apply(
        lambda row: explicit_match(row['Title'], row['Skills'], cv_skills),
        axis=1
    )
    max_word_match_contribution = job_df.apply(
        lambda row: row['word_matches'] * row['semantic_similarity'], axis=1
    ).max()

    job_df['word_match_contribution'] = job_df.apply(
        lambda row: calculate_word_match_contribution(row, cv_skills, max_word_match_contribution),
        axis=1
    )

    # Dynamically adjust the weight of word match contribution
    job_df['word_match_weight'] = job_df['Skills'].apply(
        lambda skills: determine_word_match_weight(len(skills))
    )

    # Compute the final score as a weighted combination
    job_df['final_score'] = (
        (1 - job_df['word_match_weight']) * job_df['semantic_similarity'] +
        job_df['word_match_weight'] * job_df['word_match_contribution']
    )

    # Sort by the final score
    result_df_sorted = job_df.sort_values(by='final_score', ascending=False).reset_index(drop=True)

    # Include relevant columns in the output
    result_df_sorted = result_df_sorted[[
        'Title', 'semantic_similarity', 'word_matches', 'word_match_contribution',
        'word_match_weight', 'final_score'
    ]]

    return result_df_sorted

# %%
analysis_data_new = calc_similarity_with_dynamic_weight_lenght(df_resumes, result_df, parallel=True)
analysis_data_new

# %% [markdown]
# #### with 3 diffefrent weight for words matching based on list lenght + low similairty score

# %%
def calc_similarity_with_dynamic_weight(cv_df, job_df, parallel=False):
    """
    Calculate cosine similarity between a single CV and multiple job descriptions,
    dynamically adjusting word match weight based on skill list length and semantic similarity.
    """
    from sklearn.metrics.pairwise import cosine_similarity
    from sentence_transformers import SentenceTransformer
    import os
    
    # Initialize the model
    model = SentenceTransformer('all-mpnet-base-v2')
    model.max_seq_length = 75
    model.tokenizer.padding_side = "right"

    def add_eos(input_examples):
        """Helper function to add special tokens between each skill."""
        input_examples = [input_example + model.tokenizer.eos_token for input_example in input_examples]
        return input_examples

    def explicit_match(title, skills, keywords):
        """
        Return the number of exact keyword matches in title or skills.
        """
        # Normalize the lists to lowercase and strip whitespace
        title_words = set(title.lower().split())
        skill_words = set(skill.lower().strip() for skill in skills)
        keyword_set = set(keyword.lower().strip() for keyword in keywords)

        # Check for exact matches in title or skills
        title_match = keyword_set & title_words  # Intersection of sets for title
        skills_match = keyword_set & skill_words  # Intersection of sets for skills

        # Return the total number of matches
        return len(title_match) + len(skills_match)

    # Compute dynamic weights based on skill list length and semantic similarity
    def compute_dynamic_weight(row, semantic_similarity, median_skill_count, low_similarity_threshold):
        # Skill list length weight adjustment
        if len(row['Skills']) < median_skill_count:
            skill_length_weight = 0.10  # Short skill list -> reduce weight
        else:
            skill_length_weight = 0.25  # Long skill list -> increase weight

        # Semantic similarity weight adjustment
        if semantic_similarity < low_similarity_threshold:
            similarity_weight = 0.30  # Low semantic similarity -> increase weight
        else:
            similarity_weight = 0.20  # Default weight

        # Average the two weights
        return (skill_length_weight + similarity_weight) / 2

    # Process the CV's skills
    cv_df['Skills_Text'] = cv_df['Skills'].apply(add_eos)
    cv_df['Skills_Text'] = cv_df['Skills_Text'].apply(
        lambda x: ' '.join(sorted(set(x))) if isinstance(x, list) else ''
    )
    cv_embedding = model.encode(
        cv_df['Skills_Text'].iloc[0],  # Assuming a single CV is provided
        batch_size=1,
        show_progress_bar=False
    )

    # Preprocess the job descriptions' skills
    job_df['Skills_Text'] = job_df['Skills'].apply(add_eos)
    job_df['Skills_Text'] = job_df['Skills_Text'].apply(
        lambda x: ' '.join(sorted(set(x))) if isinstance(x, list) else ''
    )
    job_embeddings = model.encode(
        job_df['Skills_Text'].tolist(),
        batch_size=32,
        num_workers=os.cpu_count() // 2 if parallel else 0,
        show_progress_bar=False
    )

    # Compute semantic similarity
    similarity_scores = cosine_similarity([cv_embedding], job_embeddings).flatten()
    job_df['semantic_similarity'] = similarity_scores

    # Calculate job skill list statistics
    job_df['job_skill_count'] = job_df['Skills'].apply(len)
    median_skill_count = job_df['job_skill_count'].median()
    low_similarity_threshold = job_df['semantic_similarity'].quantile(0.25)

    # Compute explicit matching and dynamic weight contribution
    cv_skills = cv_df['Skills'].iloc[0]
    job_df['word_matches'] = job_df.apply(
        lambda row: explicit_match(row['Title'], row['Skills'], cv_skills),
        axis=1
    )
    job_df['word_match_contribution'] = job_df.apply(
        lambda row: row['word_matches'] * row['semantic_similarity'],
        axis=1
    )

    # Normalize word match contribution
    max_contribution = job_df['word_match_contribution'].max()
    min_contribution = job_df['word_match_contribution'].min()
    if max_contribution > min_contribution:
        job_df['word_match_contribution'] = job_df['word_match_contribution'].apply(
            lambda x: (x - min_contribution) / (max_contribution - min_contribution)
        )
    else:
        job_df['word_match_contribution'] = 0  # Handle edge case if no variance exists

    # Apply dynamic weight adjustment
    job_df['dynamic_weight'] = job_df.apply(
        lambda row: compute_dynamic_weight(
            row, row['semantic_similarity'], median_skill_count, low_similarity_threshold
        ),
        axis=1
    )
    job_df['word_match_weighted'] = job_df['dynamic_weight'] * job_df['word_match_contribution']

    # Compute the final score
    job_df['final_score'] = (
        0.8 * job_df['semantic_similarity'] +  # Semantic similarity weight
        job_df['word_match_weighted']  # Dynamically weighted word match contribution
    )

    # Rank and sort the results
    job_df['rank'] = job_df['final_score'].rank(ascending=False, method='min')
    result_df_sorted = job_df.sort_values(by='rank', ascending=True)

    # Return the sorted DataFrame
    return result_df_sorted[['Title', 'semantic_similarity', 'word_matches', 'job_skill_count', 
                             'word_match_contribution', 'dynamic_weight', 'final_score', 'rank']]

# %%
analysis_data_new = calc_similarity_with_dynamic_weight(df_resumes, result_df, parallel=True)
analysis_data_new.head(30)
# Out:
#                                                  Title  semantic_similarity  \
# 148                                      Statisticians             0.707115
# 43                                     Data Scientists             0.671911
# 13                      Business Intelligence Analysts             0.598250
# 29                           Computer Systems Analysts             0.664259
# 1                                            Actuaries             0.605388
# 46                                 Database Architects             0.633678
# 57                     Financial Quantitative Analysts             0.621055
# 102                                Management Analysts             0.619413
# 58                          Financial Risk Specialists             0.617749
# 77         Fraud Examiners, Investigators and Analysts             0.630063
# 44                        Data Warehousing Specialists             0.589713
# 109                                   Online Merchants             0.565177
# 103  Market Research Analysts and Marketing Special...             0.529834
# 147                             Statistical Assistants             0.614070
# 59                   Financial and Investment Analysts             0.586504
# 110                       Operations Research Analysts             0.548283
# 82                      Health Informatics Specialists             0.581341
# 88             Information Technology Project Managers             0.578719
# 146    Software Quality Assurance Analysts and Testers             0.558491
# 138                       Search Marketing Strategists             0.493652
# 50              Electronics Engineers, Except Computer             0.552809
# 98                                  Logistics Analysts             0.549565
# 111                                       Order Clerks             0.571928
# 5    Agents and Business Managers of Artists, Perfo...             0.543222
# 32        Computer and Information Research Scientists             0.539815
# 33           Computer and Information Systems Managers             0.573960
# 149                              Supply Chain Managers             0.562079
# 133                                    Sales Engineers             0.495520
# 99                                 Logistics Engineers             0.559211
# 3                             Advertising Sales Agents             0.466008
#
#      word_matches  job_skill_count  word_match_contribution  dynamic_weight  \
# 148             5               11                 0.876994           0.225
# 43              6               28                 1.000000           0.225
# 13              5               13                 0.741975           0.225
# 29              3               16                 0.494306           0.225
# 1               4               10                 0.600662           0.225
# 46              3               17                 0.471549           0.225
# 57              3               12                 0.462156           0.225
# 102             3               11                 0.460933           0.225
# 58              3                7                 0.459695           0.225
# 77              2                9                 0.312572           0.225
# 44              3               12                 0.438832           0.225
# 109             3                7                 0.420574           0.225
# 103             4                9                 0.525698           0.225
# 147             2                5                 0.304638           0.150
# 59              2                8                 0.290963           0.225
# 110             3               10                 0.408002           0.225
# 82              2                9                 0.288401           0.225
# 88              2                9                 0.287101           0.225
# 146             2               19                 0.277066           0.225
# 138             4               11                 0.489799           0.225
# 50              2               10                 0.274247           0.225
# 98              2                9                 0.272637           0.225
# 111             2                3                 0.283732           0.150
# 5               3                3                 0.404236           0.150
# 32              2               15                 0.267800           0.225
# 33              1                8                 0.142370           0.225
# 149             1                6                 0.139423           0.225
# 133             3               11                 0.368739           0.225
# 99              1                9                 0.138711           0.225
# 3               4               13                 0.462371           0.225
#
#      final_score  rank
# 148     0.763016   1.0
# 43      0.762529   2.0
# 13      0.645545   3.0
# 29      0.642626   4.0
# 1       0.619459   5.0
# 46      0.613041   6.0
# 57      0.600829   7.0
# 102     0.599240   8.0
# 58      0.597631   9.0
# 77      0.574379  10.0
# 44      0.570507  11.0
# 109     0.546771  12.0
# 103     0.542149  13.0
# 147     0.536952  14.0
# 59      0.534670  15.0
# 110     0.530427  16.0
# 82      0.529963  17.0
# 88      0.527573  18.0
# 146     0.509133  19.0
# 138     0.505127  20.0
# 50      0.503953  21.0
# 98      0.500995  22.0
# 111     0.500102  23.0
# 5       0.495213  24.0
# 32      0.492107  25.0
# 33      0.491201  26.0
# 149     0.481033  27.0
# 133     0.479383  28.0
# 99      0.478579  29.0
# 3       0.476840  30.0

# %%
# Calculate job skill list statistics
result_df['job_skill_count'] = result_df['Skills'].apply(len)
median_skill_count = result_df['job_skill_count'].median()
low_similarity_threshold = result_df['semantic_similarity'].quantile(0.25)
low_similarity_threshold
# Out:
# 0.4152945280075073

# %%
analysis_data_new.tail(30)
# Out:
#                                                  Title  semantic_similarity  \
# 142                                  Security Managers             0.400485
# 121                       Public Relations Specialists             0.391869
# 126                                Real Estate Brokers             0.396505
# 83   Human Resources Assistants, Except Payroll and...             0.396248
# 85                         Human Resources Specialists             0.396248
# 106            Meeting, Convention, and Event Planners             0.396248
# 36                                     Cost Estimators             0.396248
# 90                              Insurance Underwriters             0.396248
# 100                           Loss Prevention Managers             0.396248
# 39                                   Credit Counselors             0.396248
# 37                                     Credit Analysts             0.396248
# 130                     Regulatory Affairs Specialists             0.396248
# 22                                 Compliance Officers             0.396248
# 139  Secretaries and Administrative Assistants, Exc...             0.396248
# 94                        Loan Interviewers and Clerks             0.396248
# 163                                     Web Developers             0.381323
# 127                           Real Estate Sales Agents             0.372755
# 119  Property, Real Estate, and Community Associati...             0.364269
# 131        Remote Sensing Scientists and Technologists             0.370162
# 81                                   Graphic Designers             0.351434
# 15                       Chief Sustainability Officers             0.379130
# 89                              Insurance Sales Agents             0.379130
# 60   First-Line Supervisors of Construction Trades ...             0.379130
# 73     First-Line Supervisors of Police and Detectives             0.379130
# 34   Computer, Automated Teller, and Office Machine...             0.379130
# 61     First-Line Supervisors of Correctional Officers             0.379130
# 113                     Payroll and Timekeeping Clerks             0.345508
# 47                                  Desktop Publishers             0.305527
# 55                              Film and Video Editors             0.301081
# 92           Interviewers, Except Eligibility and Loan             0.115635
#
#      word_matches  job_skill_count  word_match_contribution  dynamic_weight  \
# 142             1                4                 0.099340           0.200
# 121             1                9                 0.097203           0.275
# 126             1                4                 0.098352           0.200
# 83              1                5                 0.098289           0.200
# 85              1                5                 0.098289           0.200
# 106             1                5                 0.098289           0.200
# 36              1                5                 0.098289           0.200
# 90              1                5                 0.098289           0.200
# 100             1                5                 0.098289           0.200
# 39              1                5                 0.098289           0.200
# 37              1                5                 0.098289           0.200
# 130             1                5                 0.098289           0.200
# 22              1                5                 0.098289           0.200
# 139             1                5                 0.098289           0.200
# 94              1                5                 0.098289           0.200
# 163             1               40                 0.094587           0.275
# 127             1                5                 0.092461           0.200
# 119             1                6                 0.090356           0.275
# 131             1                4                 0.091818           0.200
# 81              1               13                 0.087173           0.275
# 15              0                1                 0.000000           0.200
# 89              0                1                 0.000000           0.200
# 60              0                1                 0.000000           0.200
# 73              0                1                 0.000000           0.200
# 34              0                1                 0.000000           0.200
# 61              0                1                 0.000000           0.200
# 113             1                7                 0.085703           0.275
# 47              0                8                 0.000000           0.275
# 55              0                6                 0.000000           0.275
# 92              0                1                 0.000000           0.200
#
#      final_score   rank
# 142     0.340256  136.0
# 121     0.340226  137.0
# 126     0.336874  138.0
# 83      0.336656  139.0
# 85      0.336656  139.0
# 106     0.336656  139.0
# 36      0.336656  139.0
# 90      0.336656  139.0
# 100     0.336656  139.0
# 39      0.336656  139.0
# 37      0.336656  139.0
# 130     0.336656  139.0
# 22      0.336656  139.0
# 139     0.336656  139.0
# 94      0.336656  139.0
# 163     0.331070  151.0
# 127     0.316696  152.0
# 119     0.316263  153.0
# 131     0.314493  154.0
# 81      0.305120  155.0
# 15      0.303304  156.0
# 89      0.303304  156.0
# 60      0.303304  156.0
# 73      0.303304  156.0
# 34      0.303304  160.0
# 61      0.303304  160.0
# 113     0.299975  162.0
# 47      0.244421  163.0
# 55      0.240865  164.0
# 92      0.092508  165.0
